# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://is.gd/5i8EAi" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# # Transfer Learning + CNN + CIFAR-10
#
# Se utilizará una **red neuronal convolucional** para clasificar imágenes de 32x32x3 (RGB) en 10 clases.
#
# El conjunto de datos CIFAR-10 consta de 60000 imágenes en color de 32x32 en 10 clases, con 6000 imágenes por clase. Hay 50000 imágenes de entrenamiento y 10000 de prueba.
#
#
# Referencias: https://www.cs.toronto.edu/~kriz/cifar.html
#
# <a href="https://imgbb.com/"><img src="https://i.ibb.co/SXtPQzj/CIFAR10.png" alt="CIFAR10" border="0"></a>
#
# ### **Transfer Learning**
#
# El aprendizaje por transferencia es un método de aprendizaje automático en el que **un modelo desarrollado para una tarea se reutiliza** como punto de partida para un modelo en una segunda tarea.
#
# Es un enfoque popular en el aprendizaje profundo, en el que se utilizan modelos preentrenados como punto de partida en tareas de visión por ordenador y procesamiento del lenguaje natural, dados los enormes recursos de computación y tiempo necesarios para desarrollar modelos de redes neuronales en estos problemas y por los enormes saltos de habilidad que proporcionan en problemas relacionados.
#
# <a href="https://tinyurl.com/yauxq2ap"><img src="https://machinelearningmastery.com/wp-content/uploads/2017/09/Three-ways-in-which-transfer-might-improve-learning.png" alt="experimentos" border="0" width="500" height="250"></a>

# %% [markdown]
# ## **Paso 1.** Importar las librerías necesarias

# %%
import tensorflow as tf
from tensorflow import keras
# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras_preprocessing.image import ImageDataGenerator
from keras.models import load_model 
from tensorflow.keras.optimizers import SGD, Adam
from keras.utils import np_utils
from keras import backend as K 
K.set_image_data_format('channels_last')

# to make this notebook's output stable across runs
np.random.seed(42)

# %% [markdown]
# ## **Paso 2.** Cargar el dataset
# Se cargan los datos de entrenamiento y prueba y se escala la intensidad de los píxeles en el rango de 0-1 y se convierten en flotantes, dividiéndolos por 255.

# %%
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.cifar10.load_data()
#normalizing inputs from 0-255 to 0.0-1.0 
X_train_full = X_train_full.astype('float32') 
X_test = X_test.astype('float32') 
X_train_full = X_train_full / 255.0 
X_test = X_test / 255.0

# %%
X_train_full.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# Se Divide el conjunto de entrenamiento completo en un subconjunto de validación y un subconjunto de entrenamiento (más pequeño).
#
# ![Split Data](https://806230.smushcdn.com/1739487/wp-content/uploads/2021/04/train-and-test-1-min-1.png )

# %%
from keras.utils.np_utils import to_categorical

# %%
y_train_full = to_categorical(y_train_full, num_classes = 10)
y_test = to_categorical(y_test, num_classes = 10)

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full,y_train_full, test_size=0.2)

# %% [markdown]
# ### **Paso 2.1.** Visualizar las imágenes del conjunto de datos

# %%
# initialize the label names for the CIFAR-10 dataset
class_names = ["airplane", "automobile", "bird", "cat", "deer",
	"dog", "frog", "horse", "ship", "truck"]
print(class_names[np.argmax(y_train[0])])
# Out:
# frog

# %%
n_rows = 4
n_cols = 5
plt.figure(figsize=(n_cols * 1.2, n_rows * 1.2))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(class_names[np.argmax(y_train[index])], fontsize=12)
plt.subplots_adjust(wspace=0.2, hspace=0.5)

plt.show()

# %% [markdown]
# ### Data Augmentation
#
# Dado que el conjunto de datos se compone de pequeñas fotos de objetos, no queremos utilizar aumentos que distorsionen demasiado las imágenes, para poder conservar y utilizar las características útiles de las mismas.
#
# Los tipos de aumentos aleatorios que se utilizarán son::
#  - giro horizontal,
#  - desplazamientos del 10% en la altura y la anchura de la imagen.

# %%
# create data generator
traingen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
validgen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

#Fit the augmentation method to the data
traingen.fit(X_train)
validgen.fit(X_valid)

# prepare iterator - DA_train = data augmentation x_train, y_train
DA_train = traingen.flow(X_train, y_train, batch_size=64)
DA_valid = validgen.flow(X_valid, y_valid, batch_size=64)

# %% [markdown]
# ## **Paso 3.** Creación del modelo.
#
# ### Descargar el modelo VGG 16
#
# ImageNet es un proyecto de investigación para desarrollar una gran base de datos de imágenes con anotaciones, por ejemplo, imágenes y sus descripciones.
#
# El reto de reconocimiento visual a gran escala de ImageNet es una referencia en la clasificación y detección de categorías de objetos en cientos de categorías de objetos y millones de imágenes. El reto se ha celebrado anualmente desde 2010 hasta la actualidad, atrayendo la participación de más de cincuenta instituciones.
#
# En la tarea de clasificación, las imágenes deben clasificarse en una de las 1.000 categorías diferentes.
#
# En los últimos años se han utilizado modelos de redes neuronales convolucionales muy profundas para ganar estos retos y los resultados en las tareas han superado el rendimiento humano.
#
# [Referencia](https://machinelearningmastery.com/use-pre-trained-vgg-model-classify-objects-photographs/)
#
# <a href="https://tinyurl.com/22c8hpcq"><img src="https://miro.medium.com/max/831/1*7Ip2_SeOz_BoruHEytEMlQ.png" alt="experimentos" border="0" width="500" height="350"></a>
#
#
# [Detalles VGG Keras: ](https://keras.io/api/applications/vgg/#:~:text=The%20default%20input%20size%20for,specific%20kind%20of%20input%20preprocessing.)
#
#
# La clase VGG() toma algunos argumentos que sólo pueden interesarle si desea utilizar el modelo en su propio proyecto, por ejemplo, para el aprendizaje por transferencia.
#
#
# - include_top (True): Si se incluyen o no las capas de salida del modelo. **No se necesita esto si estás ajustando el modelo en tu propio problema.**
#
# - weights ('imagenet'): Qué pesos cargar. Se puede especificar None para no cargar pesos pre-entrenados si se está interesado en entrenar el modelo desde cero.
#
# - input_tensor (None): Una nueva capa de entrada si se tiene la intención de ajustar el modelo en nuevos datos de un tamaño diferente.
#
# - input_shape (Ninguno): El tamaño de las imágenes que se espera que tome el modelo si cambias la capa de entrada. (**3 input channels, and width and height should be no smaller than 32**)
#
# - pooling (None): El tipo de pooling a utilizar cuando se entrena un nuevo conjunto de capas de salida.
#
# - clases (1000): El número de clases (por ejemplo, el tamaño del vector de salida) para el modelo.

# %%
from keras.applications.vgg19 import VGG19

# %%
np.random.seed(42)
tf.random.set_seed(42)
keras.backend.clear_session()

# %%
VGG19_model = VGG19(include_top=False,weights='imagenet',input_shape=(32,32,3),classes=y_train.shape[1])

# %%
## Modelo Secuencial Keras + VGG16
model = Sequential()
model.add(VGG19_model)
model.add(Flatten())
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 1, 1, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Add the Dense layers along with activation
model.add(Dense(1024,activation=('relu'),input_dim=512))
model.add(Dense(512,activation=('relu'))) 
model.add(Dense(256,activation=('relu'))) 
model.add(Dense(128,activation=('relu')))
model.add(Dense(10,activation=('softmax'))) #This is the classification layer

# %%
#Check final model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 1, 1, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              525312
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 21,240,010
# Trainable params: 21,240,010
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## **Paso 4.** Compilando el modelo y entrenando el modelo.
#
#
# *   **loss**: "sparse_categorical_crossentropy", se utiliza está función dado que se cuenta con un número de etiquetas escasas (sparse) - no binarias.
# *   **optimizer** = Adam.
# *   **metrics**: Exactitud (accuracy)

# %%
lr=.001

sgd=SGD(learning_rate=lr,momentum=.9,nesterov=False)
adam=Adam(learning_rate=lr, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

# %%
# Compile model 
model.compile(loss="categorical_crossentropy",optimizer=sgd,metrics=["accuracy"])

# %% [markdown]
# ### 4.1 Callbacks - Guardar el mejor modelo durante el entrenamiento
#
# - Al utilizar datos de validación durante el entrenamiento es posible salvar el ultimo mejor modelo.
# - Actualizar la variable exp_name con el nombre del experimento a realizar.

# %%
exp_name = "EXP_12_TL_VGG19"
# Tensorflow savemodel format
best_model_name = "Trained_Models/cifar10_model_" + exp_name

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint(best_model_name, save_best_only=True)
lrr= ReduceLROnPlateau(
                       monitor='val_accuracy', #Metric to be measured
                       factor=.01, #Factor by which learning rate will be reduced
                       patience=3,  #No. of epochs after which if there is no improvement in the val_acc, the learning rate is reduced
                       min_lr=1e-5) #The minimum learning rate

# %%
steps = int(X_train.shape[0] / 64)
stepsVal = int(X_valid.shape[0] / 64)

history = model.fit(DA_train, steps_per_epoch=steps, epochs=100, validation_data=(DA_valid), validation_steps=stepsVal, callbacks=[checkpoint_cb,lrr], verbose=1) 
#
# Out:
# Epoch 1/100
# 625/625 [==============================] - 20s 22ms/step - loss: 1.2550 - accuracy: 0.5546 - val_loss: 0.9118 - val_accuracy: 0.6888
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG19\assets
# Epoch 2/100
# 625/625 [==============================] - 15s 23ms/step - loss: 0.7863 - accuracy: 0.7259 - val_loss: 0.7081 - val_accuracy: 0.7533
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG19\assets
# Epoch 3/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.6623 - accuracy: 0.7710 - val_loss: 0.6840 - val_accuracy: 0.7664
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG19\assets
# Epoch 4/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.5954 - accuracy: 0.7960 - val_loss: 0.6485 - val_accuracy: 0.7823
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG19\assets
# Epoch 5/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.5347 - accuracy: 0.8143 - val_loss: 0.5358 - val_accuracy: 0.8130
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG19\assets
# Epoch 6/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.4870 - accuracy: 0.8305 - val_loss: 0.5525 - val_accuracy: 0.8125
# Epoch 7/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.4499 - accuracy: 0.8442 - val_loss: 0.5292 - val_accuracy: 0.8191
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG19\assets
# Epoch 8/100
# 625/625 [==============================] - 15s 23ms/step - loss: 0.4159 - accuracy: 0.8536 - val_loss: 0.4913 - val_accuracy: 0.8359
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG19\assets
# Epoch 9/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.3888 - accuracy: 0.8650 - val_loss: 0.5413 - val_accuracy: 0.8235
# Epoch 10/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.3712 - accuracy: 0.8699 - val_loss: 0.4556 - val_accuracy: 0.8445
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG19\assets
# Epoch 11/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.3422 - accuracy: 0.8803 - val_loss: 0.4672 - val_accuracy: 0.8450
# Epoch 12/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.3240 - accuracy: 0.8854 - val_loss: 0.4642 - val_accuracy: 0.8452
# Epoch 13/100
# 625/625 [==============================] - 15s 24ms/step - loss: 0.3060 - accuracy: 0.8942 - val_loss: 0.4575 - val_accuracy: 0.8462
# Epoch 14/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.2877 - accuracy: 0.8982 - val_loss: 0.4390 - val_accuracy: 0.8559
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG19\assets
# Epoch 15/100
# 625/625 [==============================] - 15s 24ms/step - loss: 0.2693 - accuracy: 0.9057 - val_loss: 0.4841 - val_accuracy: 0.8476
# Epoch 16/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.2569 - accuracy: 0.9100 - val_loss: 0.4658 - val_accuracy: 0.8505
# Epoch 17/100
# 625/625 [==============================] - 13s 22ms/step - loss: 0.2419 - accuracy: 0.9147 - val_loss: 0.4513 - val_accuracy: 0.8571
# Epoch 18/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.2211 - accuracy: 0.9226 - val_loss: 0.4545 - val_accuracy: 0.8564
# Epoch 19/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.2109 - accuracy: 0.9266 - val_loss: 0.4845 - val_accuracy: 0.8509
# Epoch 20/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.2013 - accuracy: 0.9299 - val_loss: 0.4531 - val_accuracy: 0.8640
# Epoch 21/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.1920 - accuracy: 0.9327 - val_loss: 0.4683 - val_accuracy: 0.8587
# Epoch 22/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.1720 - accuracy: 0.9402 - val_loss: 0.4902 - val_accuracy: 0.8542
# Epoch 23/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.1649 - accuracy: 0.9412 - val_loss: 0.4882 - val_accuracy: 0.8578
# Epoch 24/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.1993 - accuracy: 0.9352 - val_loss: 0.4316 - val_accuracy: 0.8663
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG19\assets
# Epoch 25/100
# 625/625 [==============================] - 15s 25ms/step - loss: 0.1088 - accuracy: 0.9635 - val_loss: 0.4207 - val_accuracy: 0.8726
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG19\assets
# Epoch 26/100
# 625/625 [==============================] - 16s 25ms/step - loss: 0.1026 - accuracy: 0.9655 - val_loss: 0.4246 - val_accuracy: 0.8717
# Epoch 27/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0987 - accuracy: 0.9677 - val_loss: 0.4211 - val_accuracy: 0.8742
# Epoch 28/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0955 - accuracy: 0.9688 - val_loss: 0.4241 - val_accuracy: 0.8752
# Epoch 29/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0930 - accuracy: 0.9689 - val_loss: 0.4246 - val_accuracy: 0.8752
# Epoch 30/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0892 - accuracy: 0.9702 - val_loss: 0.4224 - val_accuracy: 0.8732
# Epoch 31/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0874 - accuracy: 0.9715 - val_loss: 0.4220 - val_accuracy: 0.8773
# Epoch 32/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0840 - accuracy: 0.9728 - val_loss: 0.4361 - val_accuracy: 0.8759
# Epoch 33/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0826 - accuracy: 0.9736 - val_loss: 0.4346 - val_accuracy: 0.8743
# Epoch 34/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0830 - accuracy: 0.9732 - val_loss: 0.4304 - val_accuracy: 0.8792
# Epoch 35/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0841 - accuracy: 0.9715 - val_loss: 0.4315 - val_accuracy: 0.8778
# Epoch 36/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0808 - accuracy: 0.9736 - val_loss: 0.4241 - val_accuracy: 0.8792
# Epoch 37/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0812 - accuracy: 0.9730 - val_loss: 0.4277 - val_accuracy: 0.8755
# Epoch 38/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0812 - accuracy: 0.9735 - val_loss: 0.4308 - val_accuracy: 0.8792
# Epoch 39/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0780 - accuracy: 0.9749 - val_loss: 0.4359 - val_accuracy: 0.8754
# Epoch 40/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0767 - accuracy: 0.9754 - val_loss: 0.4345 - val_accuracy: 0.8750
# Epoch 41/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0788 - accuracy: 0.9739 - val_loss: 0.4344 - val_accuracy: 0.8760
# Epoch 42/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0773 - accuracy: 0.9743 - val_loss: 0.4276 - val_accuracy: 0.8775
# Epoch 43/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0767 - accuracy: 0.9748 - val_loss: 0.4347 - val_accuracy: 0.8761
# Epoch 44/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0738 - accuracy: 0.9758 - val_loss: 0.4417 - val_accuracy: 0.8780
# Epoch 45/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0763 - accuracy: 0.9763 - val_loss: 0.4453 - val_accuracy: 0.8795
# Epoch 46/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0746 - accuracy: 0.9757 - val_loss: 0.4333 - val_accuracy: 0.8795
# Epoch 47/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0738 - accuracy: 0.9773 - val_loss: 0.4444 - val_accuracy: 0.8768
# Epoch 48/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0739 - accuracy: 0.9758 - val_loss: 0.4384 - val_accuracy: 0.8796
# Epoch 49/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0722 - accuracy: 0.9764 - val_loss: 0.4401 - val_accuracy: 0.8774
# Epoch 50/100
# 625/625 [==============================] - 15s 23ms/step - loss: 0.0717 - accuracy: 0.9769 - val_loss: 0.4436 - val_accuracy: 0.8755
# Epoch 51/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0723 - accuracy: 0.9761 - val_loss: 0.4265 - val_accuracy: 0.8799
# Epoch 52/100
# 625/625 [==============================] - 15s 23ms/step - loss: 0.0706 - accuracy: 0.9769 - val_loss: 0.4415 - val_accuracy: 0.8793
# Epoch 53/100
# 625/625 [==============================] - 15s 23ms/step - loss: 0.0720 - accuracy: 0.9771 - val_loss: 0.4332 - val_accuracy: 0.8787
# Epoch 54/100
# 625/625 [==============================] - 15s 23ms/step - loss: 0.0695 - accuracy: 0.9775 - val_loss: 0.4411 - val_accuracy: 0.8754
# Epoch 55/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0705 - accuracy: 0.9765 - val_loss: 0.4518 - val_accuracy: 0.8776
# Epoch 56/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0696 - accuracy: 0.9771 - val_loss: 0.4464 - val_accuracy: 0.8767
# Epoch 57/100
# 625/625 [==============================] - 15s 23ms/step - loss: 0.0677 - accuracy: 0.9777 - val_loss: 0.4444 - val_accuracy: 0.8772
# Epoch 58/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0692 - accuracy: 0.9778 - val_loss: 0.4467 - val_accuracy: 0.8759
# Epoch 59/100
# 625/625 [==============================] - 15s 23ms/step - loss: 0.0680 - accuracy: 0.9767 - val_loss: 0.4417 - val_accuracy: 0.8787
# Epoch 60/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0676 - accuracy: 0.9780 - val_loss: 0.4492 - val_accuracy: 0.8816
# Epoch 61/100
# 625/625 [==============================] - 15s 24ms/step - loss: 0.0662 - accuracy: 0.9794 - val_loss: 0.4448 - val_accuracy: 0.8789
# Epoch 62/100
# 625/625 [==============================] - 16s 26ms/step - loss: 0.0657 - accuracy: 0.9790 - val_loss: 0.4480 - val_accuracy: 0.8784
# Epoch 63/100
# 625/625 [==============================] - 15s 23ms/step - loss: 0.0653 - accuracy: 0.9782 - val_loss: 0.4591 - val_accuracy: 0.8781
# Epoch 64/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0664 - accuracy: 0.9787 - val_loss: 0.4452 - val_accuracy: 0.8780
# Epoch 65/100
# 625/625 [==============================] - 15s 23ms/step - loss: 0.0644 - accuracy: 0.9786 - val_loss: 0.4482 - val_accuracy: 0.8787
# Epoch 66/100
# 625/625 [==============================] - 15s 23ms/step - loss: 0.0684 - accuracy: 0.9779 - val_loss: 0.4565 - val_accuracy: 0.8779
# Epoch 67/100
# 625/625 [==============================] - 15s 23ms/step - loss: 0.0669 - accuracy: 0.9783 - val_loss: 0.4509 - val_accuracy: 0.8786
# Epoch 68/100
# 625/625 [==============================] - 15s 24ms/step - loss: 0.0650 - accuracy: 0.9787 - val_loss: 0.4496 - val_accuracy: 0.8780
# Epoch 69/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0651 - accuracy: 0.9794 - val_loss: 0.4635 - val_accuracy: 0.8772
# Epoch 70/100
# 625/625 [==============================] - 15s 23ms/step - loss: 0.0633 - accuracy: 0.9797 - val_loss: 0.4506 - val_accuracy: 0.8782
# Epoch 71/100
# 625/625 [==============================] - 15s 23ms/step - loss: 0.0619 - accuracy: 0.9798 - val_loss: 0.4570 - val_accuracy: 0.8759
# Epoch 72/100
# 625/625 [==============================] - 15s 23ms/step - loss: 0.0634 - accuracy: 0.9790 - val_loss: 0.4618 - val_accuracy: 0.8754
# Epoch 73/100
# 625/625 [==============================] - 16s 25ms/step - loss: 0.0637 - accuracy: 0.9797 - val_loss: 0.4515 - val_accuracy: 0.8792
# Epoch 74/100
# 625/625 [==============================] - 16s 25ms/step - loss: 0.0627 - accuracy: 0.9796 - val_loss: 0.4571 - val_accuracy: 0.8802
# Epoch 75/100
# 625/625 [==============================] - 16s 25ms/step - loss: 0.0627 - accuracy: 0.9792 - val_loss: 0.4616 - val_accuracy: 0.8799
# Epoch 76/100
# 625/625 [==============================] - 15s 24ms/step - loss: 0.0628 - accuracy: 0.9800 - val_loss: 0.4561 - val_accuracy: 0.8798
# Epoch 77/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0620 - accuracy: 0.9797 - val_loss: 0.4626 - val_accuracy: 0.8787
# Epoch 78/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0595 - accuracy: 0.9814 - val_loss: 0.4579 - val_accuracy: 0.8792
# Epoch 79/100
# 625/625 [==============================] - 15s 24ms/step - loss: 0.0621 - accuracy: 0.9805 - val_loss: 0.4566 - val_accuracy: 0.8761
# Epoch 80/100
# 625/625 [==============================] - 15s 24ms/step - loss: 0.0604 - accuracy: 0.9807 - val_loss: 0.4587 - val_accuracy: 0.8817
# Epoch 81/100
# 625/625 [==============================] - 15s 24ms/step - loss: 0.0627 - accuracy: 0.9793 - val_loss: 0.4647 - val_accuracy: 0.8789
# Epoch 82/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0598 - accuracy: 0.9806 - val_loss: 0.4706 - val_accuracy: 0.8784
# Epoch 83/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0596 - accuracy: 0.9804 - val_loss: 0.4576 - val_accuracy: 0.8774
# Epoch 84/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0590 - accuracy: 0.9811 - val_loss: 0.4658 - val_accuracy: 0.8798
# Epoch 85/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0598 - accuracy: 0.9803 - val_loss: 0.4655 - val_accuracy: 0.8789
# Epoch 86/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0588 - accuracy: 0.9808 - val_loss: 0.4672 - val_accuracy: 0.8763
# Epoch 87/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0583 - accuracy: 0.9810 - val_loss: 0.4729 - val_accuracy: 0.8773
# Epoch 88/100
# 625/625 [==============================] - 15s 24ms/step - loss: 0.0583 - accuracy: 0.9811 - val_loss: 0.4688 - val_accuracy: 0.8795
# Epoch 89/100
# 625/625 [==============================] - 15s 24ms/step - loss: 0.0591 - accuracy: 0.9797 - val_loss: 0.4621 - val_accuracy: 0.8786
# Epoch 90/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0589 - accuracy: 0.9812 - val_loss: 0.4572 - val_accuracy: 0.8816
# Epoch 91/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0590 - accuracy: 0.9808 - val_loss: 0.4728 - val_accuracy: 0.8773
# Epoch 92/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0586 - accuracy: 0.9805 - val_loss: 0.4755 - val_accuracy: 0.8769
# Epoch 93/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0564 - accuracy: 0.9810 - val_loss: 0.4680 - val_accuracy: 0.8803
# Epoch 94/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0560 - accuracy: 0.9817 - val_loss: 0.4744 - val_accuracy: 0.8755
# Epoch 95/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0572 - accuracy: 0.9815 - val_loss: 0.4697 - val_accuracy: 0.8802
# Epoch 96/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0555 - accuracy: 0.9824 - val_loss: 0.4776 - val_accuracy: 0.8765
# Epoch 97/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0557 - accuracy: 0.9812 - val_loss: 0.4618 - val_accuracy: 0.8822
# Epoch 98/100
# 625/625 [==============================] - 15s 24ms/step - loss: 0.0567 - accuracy: 0.9818 - val_loss: 0.4721 - val_accuracy: 0.8784
# Epoch 99/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0558 - accuracy: 0.9822 - val_loss: 0.4741 - val_accuracy: 0.8778
# Epoch 100/100
# 625/625 [==============================] - 15s 23ms/step - loss: 0.0547 - accuracy: 0.9827 - val_loss: 0.4743 - val_accuracy: 0.8771

# %%
# se utiliza pandas para visualizar la información almacenada en el diccionario de historia de entrenamiento y graficarla. 
import pandas as pd

pd.DataFrame(history.history).plot(figsize=(6, 3))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# ## **Paso 5.** Evaluación del modelo.
# Se evalua el modelo con el conjunto de datos de prueba.
#
# - X_train: Conjunto de datos de entrenamiento.
# - y_train: Etiquetas de los datos de entrenamiento.
# - X_valid: Conjunto de datos de validación.
# - y_valid: Etiquetas de los datos de validación.
# - X_test: Conjunto de datos de prueba.
# - y_test: Etiquetas de los datos de prueba.

# %%
model = load_model(best_model_name)

# %%
scores_train = model.evaluate(X_train, y_train)
scores_valid = model.evaluate(X_valid, y_valid)
scores_test = model.evaluate(X_test, y_test)
# Out:
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.0830 - accuracy: 0.9727
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4037 - accuracy: 0.8789
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4176 - accuracy: 0.8741

# %%
print('train loss:', round(scores_train[0]*100,2), '%')
print('valid loss:', round(scores_valid[0]*100,2), '%')
print('test loss:', round(scores_test[0]*100,2), '%')
print("\n")
print('train accuracy:', round(scores_train[1]*100,2), '%')
print('valid accuracy:', round(scores_valid[1]*100,2), '%')
print('test accuracy:', round(scores_test[1]*100,2), '%')
# Out:
# train loss: 8.3 %
# valid loss: 40.37 %
# test loss: 41.76 %
#
#
# train accuracy: 97.27 %
# valid accuracy: 87.89 %
# test accuracy: 87.41 %

# %% [markdown]
# ## **Paso 6.** Usando el modelo para hacer predicciones.
#
# Se toman 5 instancias del set de prueba para hacer la predicción. y se imprime la matriz de probabilidad para cada una de las instancias.

# %%
X_new = X_test[10:15]
y_proba = model.predict(X_new)

# %% [markdown]
# Visualizar las predicciones

# %%
classes_x = np.argmax(y_proba,axis=1)
np.array(class_names)[classes_x]
# Out:
# array(['airplane', 'truck', 'frog', 'horse', 'truck'], dtype='<U10')

# %% [markdown]
# Visualizar los valores reales

# %%
y_new = y_test[10:15]
plt.figure(figsize=(7.2, 2.4))
for index, image in enumerate(X_new):
    plt.subplot(1, 5, index + 1)
    plt.imshow(image, cmap="binary", interpolation="nearest")
    plt.axis('off')
    plt.title(class_names[np.argmax(y_new[index])], fontsize=10)
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()
