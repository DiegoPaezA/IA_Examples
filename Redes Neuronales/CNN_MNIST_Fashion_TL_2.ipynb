# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://is.gd/hoIMVZ" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ## Transfer Learning + CNN - MNIST Fashion Dataset
#
# En este notebook utilizaremos el dataset de MNIST Fashion para entrenar una red neuronal convolucional (CNN) para clasificar imágenes de ropa.
#
# El dataset MNIST Fashion contiene 70,000 imágenes en escala de grises de 28x28 píxeles, cada una de las cuales pertenece a una de las 10 clases de ropa. El dataset está dividido en 60,000 imágenes de entrenamiento y 10,000 imágenes de prueba. Cada imagen está etiquetada con una sola etiqueta de clase, que es un entero de 0 a 9.
#
# ### **Transfer Learning**
#
# El aprendizaje por transferencia es un método de aprendizaje automático en el que **un modelo desarrollado para una tarea se reutiliza** como punto de partida para un modelo en una segunda tarea.
#
# Es un enfoque popular en el aprendizaje profundo, en el que se utilizan modelos preentrenados como punto de partida en tareas de visión por ordenador y procesamiento del lenguaje natural, dados los enormes recursos de computación y tiempo necesarios para desarrollar modelos de redes neuronales en estos problemas y por los enormes saltos de habilidad que proporcionan en problemas relacionados.
#
# <a href="https://tinyurl.com/yauxq2ap"><img src="https://machinelearningmastery.com/wp-content/uploads/2017/09/Three-ways-in-which-transfer-might-improve-learning.png" alt="experimentos" border="0" width="500" height="250"></a>

# %% [markdown]
# ## **Paso 1.** Importar las librerías

# %%
import tensorflow as tf
from tensorflow import keras
# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPooling2D, BatchNormalization
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras_preprocessing.image import ImageDataGenerator
from keras.models import load_model 
from keras.constraints import maxnorm
from tensorflow.keras.optimizers import SGD
from keras.utils import np_utils
from keras import backend as K 
K.set_image_data_format('channels_last')



# to make this notebook's output stable across runs
np.random.seed(42)

# %% [markdown]
# ## **Paso 2.** Cargar el dataset.
#
# Se utilizará el Fashion MNIST. El dataset contiene 70,000 imagenes en escala de grises de 28x28 pixeles cada una, organizadas en 10 clases.
#
# * Se utiliza keras para cargar el dataset.
# * Se realiza la separación del batch para entrenamiento y testeo, dejando 60,000 imagenes en escala de griste de de 28x28 pixeles para el set de entrenamiento.

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()

# %%
# transform to rgb as required by VGG
X_train_full=tf.image.grayscale_to_rgb(tf.expand_dims(X_train_full, axis=3)) 
X_test=tf.image.grayscale_to_rgb(tf.expand_dims(X_test, axis=3))

#resize to minimum size of (32x32
X_train_full=tf.image.resize_with_pad(X_train_full,32,32)
X_test=tf.image.resize_with_pad(X_test,32,32)

# %%
X_train_full = X_train_full / 255.0
X_test = X_test / 255.0

X_train_full = X_train_full.numpy()
X_test = X_test.numpy()

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full,y_train_full, test_size=0.1)

# %%
X_train.shape
# Out:
# (54000, 32, 32, 3)

# %% [markdown]
# ### Las etiquetas son los IDs de las clases, representados de 0 a 9.

# %%
# nombres de las clases
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# La primera imagen en el set de entrenamiento es una Coat. 
class_names[y_train_full[0]]
# Out:
# 'Ankle boot'

# %%
#Imagenes del dataset
n_rows = 4
n_cols = 5
plt.figure(figsize=(n_cols * 1.2, n_rows * 1.2))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train_full[index], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(class_names[y_train_full[index]], fontsize=12)
plt.subplots_adjust(wspace=0.2, hspace=0.5)

plt.show()

# %% [markdown]
# ### Data Augmentation
#
# Dado que el conjunto de datos se compone de pequeñas fotos de objetos, no queremos utilizar aumentos que distorsionen demasiado las imágenes, para poder conservar y utilizar las características útiles de las mismas.
#
# Los tipos de aumentos aleatorios que se utilizarán son::
#  - giro horizontal,
#  - desplazamientos del 10% en la altura y la anchura de la imagen.

# %%
# create data generator
traingen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
validgen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

#Fit the augmentation method to the data
traingen.fit(X_train)
validgen.fit(X_valid)

# prepare iterator - DA_train = data augmentation x_train, y_train
DA_train = traingen.flow(X_train, y_train, batch_size=64)
DA_valid = validgen.flow(X_valid, y_valid, batch_size=64)

# %% [markdown]
# ## **Paso 3.** Creación del modelo.
#
# ### Descargar el modelo VGG 16
#
# ImageNet es un proyecto de investigación para desarrollar una gran base de datos de imágenes con anotaciones, por ejemplo, imágenes y sus descripciones.
#
# El reto de reconocimiento visual a gran escala de ImageNet es una referencia en la clasificación y detección de categorías de objetos en cientos de categorías de objetos y millones de imágenes. El reto se ha celebrado anualmente desde 2010 hasta la actualidad, atrayendo la participación de más de cincuenta instituciones.
#
# En la tarea de clasificación, las imágenes deben clasificarse en una de las 1.000 categorías diferentes.
#
# En los últimos años se han utilizado modelos de redes neuronales convolucionales muy profundas para ganar estos retos y los resultados en las tareas han superado el rendimiento humano.
#
# [Referencia](https://machinelearningmastery.com/use-pre-trained-vgg-model-classify-objects-photographs/)
#
# <a href="https://tinyurl.com/22c8hpcq"><img src="https://miro.medium.com/max/831/1*7Ip2_SeOz_BoruHEytEMlQ.png" alt="experimentos" border="0" width="500" height="350"></a>
#
#
# [Detalles VGG Keras: ](https://keras.io/api/applications/vgg/#:~:text=The%20default%20input%20size%20for,specific%20kind%20of%20input%20preprocessing.)
#
#
# La clase VGG() toma algunos argumentos que sólo pueden interesarle si desea utilizar el modelo en su propio proyecto, por ejemplo, para el aprendizaje por transferencia.
#
#
# - include_top (True): Si se incluyen o no las capas de salida del modelo. **No se necesita esto si estás ajustando el modelo en tu propio problema.**
#
# - weights ('imagenet'): Qué pesos cargar. Se puede especificar None para no cargar pesos pre-entrenados si se está interesado en entrenar el modelo desde cero.
#
# - input_tensor (None): Una nueva capa de entrada si se tiene la intención de ajustar el modelo en nuevos datos de un tamaño diferente.
#
# - input_shape (Ninguno): El tamaño de las imágenes que se espera que tome el modelo si cambias la capa de entrada. (**3 input channels, and width and height should be no smaller than 32**)
#
# - pooling (None): El tipo de pooling a utilizar cuando se entrena un nuevo conjunto de capas de salida.
#
# - clases (1000): El número de clases (por ejemplo, el tamaño del vector de salida) para el modelo.

# %%
from keras.applications.vgg19 import VGG19

# %%
np.random.seed(42)
tf.random.set_seed(42)
keras.backend.clear_session()

# %%
VGG19_model = VGG19(include_top=False,weights='imagenet',input_shape=(32,32,3),classes=y_train.shape[1])

# %%
## Modelo Secuencial Keras + VGG16
model = Sequential()
model.add(VGG19_model)
model.add(Flatten())
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 1, 1, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %%
#Add the Dense layers along with activation
model.add(Dense(1024,activation=('relu'),input_dim=512))
model.add(Dense(512,activation=('relu'))) 
model.add(Dense(256,activation=('relu'))) 
model.add(Dense(128,activation=('relu')))
model.add(Dense(10,activation=('softmax'))) #This is the classification layer

# %% [markdown]
# ## **Paso 4.** Compilando el modelo y entrenando el modelo.
#
#
# *   **loss**: "sparse_categorical_crossentropy", se utiliza está función dado que se cuenta con un número de etiquetas escasas (sparse) - no binarias.
# *   **optimizer** = Adam.
# *   **metrics**: Exactitud (accuracy)

# %%
model.compile(loss="sparse_categorical_crossentropy",optimizer="adam",metrics=["accuracy"])

# %% [markdown]
# ### 4.1 Callbacks - Guardar el mejor modelo durante el entrenamiento
#
# - Al utilizar datos de validación durante el entrenamiento es posible salvar el ultimo mejor modelo.
# - Actualizar la variable exp_name con el nombre del experimento a realizar.

# %%
exp_name = "EXP_12_TL_VGG19"
# Tensorflow savemodel format
best_model_name = "Trained_Models/fashion_model_" + exp_name

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint(best_model_name, save_best_only=True)
lrr= ReduceLROnPlateau(
                       monitor='val_accuracy', #Metric to be measured
                       factor=.01, #Factor by which learning rate will be reduced
                       patience=3,  #No. of epochs after which if there is no improvement in the val_acc, the learning rate is reduced
                       min_lr=1e-5) #The minimum learning rate

# %%
steps = int(X_train.shape[0] / 64)
stepsVal = int(X_valid.shape[0] / 64)

history = model.fit(DA_train, steps_per_epoch=steps, epochs=100, validation_data=(DA_valid), validation_steps=stepsVal, callbacks=[checkpoint_cb,lrr], verbose=1)
# Out:
# Entrenando modelo EXP_11_TL_VGG16
# Epoch 1/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.9599 - accuracy: 0.6537 - val_loss: 0.5848 - val_accuracy: 0.7860
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 2/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.6635 - accuracy: 0.7709 - val_loss: 0.5453 - val_accuracy: 0.8028
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 3/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.6171 - accuracy: 0.7874 - val_loss: 0.5079 - val_accuracy: 0.8110
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 4/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.5895 - accuracy: 0.7959 - val_loss: 0.4890 - val_accuracy: 0.8197
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 5/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.5775 - accuracy: 0.7986 - val_loss: 0.4721 - val_accuracy: 0.8205
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 6/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.5592 - accuracy: 0.8055 - val_loss: 0.4736 - val_accuracy: 0.8208
# Epoch 7/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.5525 - accuracy: 0.8070 - val_loss: 0.4708 - val_accuracy: 0.8282
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 8/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.5436 - accuracy: 0.8098 - val_loss: 0.4589 - val_accuracy: 0.8337
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 9/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.5351 - accuracy: 0.8135 - val_loss: 0.4591 - val_accuracy: 0.8290
# Epoch 10/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.5272 - accuracy: 0.8167 - val_loss: 0.4523 - val_accuracy: 0.8307
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 11/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.5227 - accuracy: 0.8162 - val_loss: 0.4474 - val_accuracy: 0.8367
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 12/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.5260 - accuracy: 0.8188 - val_loss: 0.4359 - val_accuracy: 0.8427
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 13/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.5153 - accuracy: 0.8188 - val_loss: 0.4471 - val_accuracy: 0.8402
# Epoch 14/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.5221 - accuracy: 0.8172 - val_loss: 0.4392 - val_accuracy: 0.8348
# Epoch 15/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.5158 - accuracy: 0.8202 - val_loss: 0.4292 - val_accuracy: 0.8405
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 16/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4895 - accuracy: 0.8298 - val_loss: 0.4170 - val_accuracy: 0.8445
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 17/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4784 - accuracy: 0.8342 - val_loss: 0.4174 - val_accuracy: 0.8505
# Epoch 18/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4766 - accuracy: 0.8333 - val_loss: 0.4190 - val_accuracy: 0.8448
# Epoch 19/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4674 - accuracy: 0.8356 - val_loss: 0.4087 - val_accuracy: 0.8477
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 20/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4682 - accuracy: 0.8360 - val_loss: 0.4086 - val_accuracy: 0.8470
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 21/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4601 - accuracy: 0.8375 - val_loss: 0.4169 - val_accuracy: 0.8477
# Epoch 22/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4562 - accuracy: 0.8388 - val_loss: 0.4108 - val_accuracy: 0.8497
# Epoch 23/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4591 - accuracy: 0.8380 - val_loss: 0.4054 - val_accuracy: 0.8490
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 24/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4534 - accuracy: 0.8407 - val_loss: 0.4140 - val_accuracy: 0.8520
# Epoch 25/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4548 - accuracy: 0.8394 - val_loss: 0.4120 - val_accuracy: 0.8473
# Epoch 26/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4509 - accuracy: 0.8416 - val_loss: 0.4120 - val_accuracy: 0.8483
# Epoch 27/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4486 - accuracy: 0.8438 - val_loss: 0.4172 - val_accuracy: 0.8440
# Epoch 28/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4499 - accuracy: 0.8418 - val_loss: 0.4125 - val_accuracy: 0.8473
# Epoch 29/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4456 - accuracy: 0.8425 - val_loss: 0.4087 - val_accuracy: 0.8478
# Epoch 30/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4435 - accuracy: 0.8435 - val_loss: 0.4054 - val_accuracy: 0.8503
# Epoch 31/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4498 - accuracy: 0.8427 - val_loss: 0.4119 - val_accuracy: 0.8525
# Epoch 32/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4470 - accuracy: 0.8412 - val_loss: 0.4026 - val_accuracy: 0.8467
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 33/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4431 - accuracy: 0.8446 - val_loss: 0.4056 - val_accuracy: 0.8505
# Epoch 34/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4413 - accuracy: 0.8439 - val_loss: 0.4040 - val_accuracy: 0.8487
# Epoch 35/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4400 - accuracy: 0.8434 - val_loss: 0.4111 - val_accuracy: 0.8488
# Epoch 36/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4425 - accuracy: 0.8425 - val_loss: 0.4057 - val_accuracy: 0.8515
# Epoch 37/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4405 - accuracy: 0.8447 - val_loss: 0.4063 - val_accuracy: 0.8487
# Epoch 38/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4352 - accuracy: 0.8447 - val_loss: 0.4061 - val_accuracy: 0.8462
# Epoch 39/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4376 - accuracy: 0.8447 - val_loss: 0.4041 - val_accuracy: 0.8527
# Epoch 40/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4380 - accuracy: 0.8463 - val_loss: 0.4098 - val_accuracy: 0.8475
# Epoch 41/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4403 - accuracy: 0.8426 - val_loss: 0.4077 - val_accuracy: 0.8478
# Epoch 42/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4393 - accuracy: 0.8460 - val_loss: 0.3985 - val_accuracy: 0.8513
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 43/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4357 - accuracy: 0.8450 - val_loss: 0.4047 - val_accuracy: 0.8510
# Epoch 44/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4363 - accuracy: 0.8451 - val_loss: 0.4048 - val_accuracy: 0.8490
# Epoch 45/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4370 - accuracy: 0.8457 - val_loss: 0.4028 - val_accuracy: 0.8502
# Epoch 46/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4352 - accuracy: 0.8466 - val_loss: 0.4078 - val_accuracy: 0.8483
# Epoch 47/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4342 - accuracy: 0.8468 - val_loss: 0.4083 - val_accuracy: 0.8477
# Epoch 48/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4378 - accuracy: 0.8459 - val_loss: 0.4108 - val_accuracy: 0.8465
# Epoch 49/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4348 - accuracy: 0.8458 - val_loss: 0.3984 - val_accuracy: 0.8520
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 50/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4290 - accuracy: 0.8478 - val_loss: 0.4066 - val_accuracy: 0.8535
# Epoch 51/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4362 - accuracy: 0.8461 - val_loss: 0.4090 - val_accuracy: 0.8490
# Epoch 52/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4333 - accuracy: 0.8456 - val_loss: 0.4064 - val_accuracy: 0.8478
# Epoch 53/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4339 - accuracy: 0.8457 - val_loss: 0.3923 - val_accuracy: 0.8567
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 54/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4351 - accuracy: 0.8462 - val_loss: 0.3956 - val_accuracy: 0.8540
# Epoch 55/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4346 - accuracy: 0.8434 - val_loss: 0.4047 - val_accuracy: 0.8510
# Epoch 56/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4315 - accuracy: 0.8470 - val_loss: 0.4036 - val_accuracy: 0.8517
# Epoch 57/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4302 - accuracy: 0.8464 - val_loss: 0.3942 - val_accuracy: 0.8523
# Epoch 58/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4304 - accuracy: 0.8473 - val_loss: 0.4047 - val_accuracy: 0.8475
# Epoch 59/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4300 - accuracy: 0.8469 - val_loss: 0.4077 - val_accuracy: 0.8470
# Epoch 60/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4297 - accuracy: 0.8484 - val_loss: 0.4033 - val_accuracy: 0.8495
# Epoch 61/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4290 - accuracy: 0.8486 - val_loss: 0.3985 - val_accuracy: 0.8488
# Epoch 62/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4283 - accuracy: 0.8477 - val_loss: 0.3959 - val_accuracy: 0.8522
# Epoch 63/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4267 - accuracy: 0.8478 - val_loss: 0.4032 - val_accuracy: 0.8527
# Epoch 64/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4301 - accuracy: 0.8482 - val_loss: 0.3945 - val_accuracy: 0.8523
# Epoch 65/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4310 - accuracy: 0.8471 - val_loss: 0.3972 - val_accuracy: 0.8533
# Epoch 66/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4297 - accuracy: 0.8472 - val_loss: 0.4033 - val_accuracy: 0.8488
# Epoch 67/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4303 - accuracy: 0.8477 - val_loss: 0.4028 - val_accuracy: 0.8530
# Epoch 68/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4281 - accuracy: 0.8475 - val_loss: 0.4099 - val_accuracy: 0.8437
# Epoch 69/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4270 - accuracy: 0.8487 - val_loss: 0.4004 - val_accuracy: 0.8545
# Epoch 70/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4314 - accuracy: 0.8472 - val_loss: 0.3953 - val_accuracy: 0.8543
# Epoch 71/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4241 - accuracy: 0.8488 - val_loss: 0.4073 - val_accuracy: 0.8467
# Epoch 72/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4270 - accuracy: 0.8475 - val_loss: 0.3989 - val_accuracy: 0.8505
# Epoch 73/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4272 - accuracy: 0.8490 - val_loss: 0.3976 - val_accuracy: 0.8582
# Epoch 74/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4281 - accuracy: 0.8480 - val_loss: 0.4052 - val_accuracy: 0.8502
# Epoch 75/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4263 - accuracy: 0.8477 - val_loss: 0.3985 - val_accuracy: 0.8520
# Epoch 76/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4255 - accuracy: 0.8487 - val_loss: 0.3983 - val_accuracy: 0.8515
# Epoch 77/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4263 - accuracy: 0.8490 - val_loss: 0.3948 - val_accuracy: 0.8533
# Epoch 78/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4271 - accuracy: 0.8488 - val_loss: 0.4008 - val_accuracy: 0.8495
# Epoch 79/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4277 - accuracy: 0.8490 - val_loss: 0.3977 - val_accuracy: 0.8500
# Epoch 80/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4192 - accuracy: 0.8505 - val_loss: 0.3928 - val_accuracy: 0.8542
# Epoch 81/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4245 - accuracy: 0.8484 - val_loss: 0.3957 - val_accuracy: 0.8530
# Epoch 82/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4227 - accuracy: 0.8503 - val_loss: 0.3940 - val_accuracy: 0.8545
# Epoch 83/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4232 - accuracy: 0.8511 - val_loss: 0.4015 - val_accuracy: 0.8508
# Epoch 84/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4216 - accuracy: 0.8496 - val_loss: 0.4093 - val_accuracy: 0.8467
# Epoch 85/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4240 - accuracy: 0.8513 - val_loss: 0.4024 - val_accuracy: 0.8488
# Epoch 86/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4207 - accuracy: 0.8494 - val_loss: 0.4026 - val_accuracy: 0.8523
# Epoch 87/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4178 - accuracy: 0.8520 - val_loss: 0.4078 - val_accuracy: 0.8455
# Epoch 88/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4255 - accuracy: 0.8503 - val_loss: 0.4053 - val_accuracy: 0.8537
# Epoch 89/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4230 - accuracy: 0.8486 - val_loss: 0.3956 - val_accuracy: 0.8555
# Epoch 90/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4227 - accuracy: 0.8500 - val_loss: 0.3900 - val_accuracy: 0.8540
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_TL_VGG16\assets
# Epoch 91/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4206 - accuracy: 0.8526 - val_loss: 0.3977 - val_accuracy: 0.8542
# Epoch 92/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4204 - accuracy: 0.8499 - val_loss: 0.3956 - val_accuracy: 0.8520
# Epoch 93/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4208 - accuracy: 0.8495 - val_loss: 0.3964 - val_accuracy: 0.8558
# Epoch 94/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4209 - accuracy: 0.8497 - val_loss: 0.3929 - val_accuracy: 0.8553
# Epoch 95/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4233 - accuracy: 0.8473 - val_loss: 0.3982 - val_accuracy: 0.8512
# Epoch 96/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4233 - accuracy: 0.8511 - val_loss: 0.3908 - val_accuracy: 0.8513
# Epoch 97/100
# 843/843 [==============================] - 15s 18ms/step - loss: 0.4201 - accuracy: 0.8515 - val_loss: 0.3968 - val_accuracy: 0.8545
# Epoch 98/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4196 - accuracy: 0.8504 - val_loss: 0.3964 - val_accuracy: 0.8557
# Epoch 99/100
# 843/843 [==============================] - 14s 17ms/step - loss: 0.4154 - accuracy: 0.8519 - val_loss: 0.3939 - val_accuracy: 0.8540
# Epoch 100/100
# 843/843 [==============================] - 15s 17ms/step - loss: 0.4209 - accuracy: 0.8523 - val_loss: 0.4043 - val_accuracy: 0.8463

# %%
# se utiliza pandas para visualizar la información almacenada en el diccionario de historia de entrenamiento y graficarla. 
import pandas as pd

pd.DataFrame(history.history).plot(figsize=(6, 4))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# ## **Paso 5.** Evaluación del modelo.
# Se evalua el modelo con el conjunto de datos de prueba.
#
# - X_train: Conjunto de datos de entrenamiento.
# - y_train: Etiquetas de los datos de entrenamiento.
# - X_valid: Conjunto de datos de validación.
# - y_valid: Etiquetas de los datos de validación.
# - X_test: Conjunto de datos de prueba.
# - y_test: Etiquetas de los datos de prueba.

# %%
model = load_model(best_model_name)

# %%
scores_train = model.evaluate(X_train, y_train)
scores_valid = model.evaluate(X_valid, y_valid)
scores_test = model.evaluate(X_test, y_test)
# Out:
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3385 - accuracy: 0.8721
# 188/188 [==============================] - 1s 5ms/step - loss: 0.3778 - accuracy: 0.8582
# 313/313 [==============================] - 2s 5ms/step - loss: 0.3887 - accuracy: 0.8583

# %%
print('train loss:', round(scores_train[0]*100,2), '%')
print('valid loss:', round(scores_valid[0]*100,2), '%')
print('test loss:', round(scores_test[0]*100,2), '%')
print("\n")
print('train accuracy:', round(scores_train[1]*100,2), '%')
print('valid accuracy:', round(scores_valid[1]*100,2), '%')
print('test accuracy:', round(scores_test[1]*100,2), '%')
# Out:
# train loss: 33.85 %
# valid loss: 37.78 %
# test loss: 38.87 %
#
#
# train accuracy: 87.21 %
# valid accuracy: 85.82 %
# test accuracy: 85.83 %

# %% [markdown]
# ## **Paso 6.** Usando el modelo para hacer predicciones.
#
# Se toman 5 instancias del set de prueba para hacer la predicción. y se imprime la matriz de probabilidad para cada una de las instancias.

# %%
X_new = X_test[10:15]
y_proba = model.predict(X_new)

# %%
classes_x = np.argmax(y_proba,axis=1)

# %%
# Valores predichos
np.array(class_names)[classes_x]
# Out:
# array(['Coat', 'Sandal', 'Sneaker', 'Dress', 'Coat'], dtype='<U11')

# %%
y_new = y_test[10:15]
plt.figure(figsize=(6, 2))
for index, image in enumerate(X_new):
    plt.subplot(1, 5, index + 1)
    plt.imshow(image, cmap="binary", interpolation="nearest")
    plt.axis('off')
    plt.title(class_names[y_new[index]], fontsize=10)
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()
