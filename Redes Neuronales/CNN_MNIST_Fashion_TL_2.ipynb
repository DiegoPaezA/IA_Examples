# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://is.gd/hoIMVZ" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ## Transfer Learning + CNN - MNIST Fashion Dataset
#
# En este notebook utilizaremos el dataset de MNIST Fashion para entrenar una red neuronal convolucional (CNN) para clasificar imágenes de ropa.
#
# El dataset MNIST Fashion contiene 70,000 imágenes en escala de grises de 28x28 píxeles, cada una de las cuales pertenece a una de las 10 clases de ropa. El dataset está dividido en 60,000 imágenes de entrenamiento y 10,000 imágenes de prueba. Cada imagen está etiquetada con una sola etiqueta de clase, que es un entero de 0 a 9.
#
# ### **Transfer Learning**
#
# El aprendizaje por transferencia es un método de aprendizaje automático en el que **un modelo desarrollado para una tarea se reutiliza** como punto de partida para un modelo en una segunda tarea.
#
# Es un enfoque popular en el aprendizaje profundo, en el que se utilizan modelos preentrenados como punto de partida en tareas de visión por ordenador y procesamiento del lenguaje natural, dados los enormes recursos de computación y tiempo necesarios para desarrollar modelos de redes neuronales en estos problemas y por los enormes saltos de habilidad que proporcionan en problemas relacionados.
#
# <a href="https://tinyurl.com/yauxq2ap"><img src="https://machinelearningmastery.com/wp-content/uploads/2017/09/Three-ways-in-which-transfer-might-improve-learning.png" alt="experimentos" border="0" width="500" height="250"></a>

# %% [markdown]
# ## **Paso 1.** Importar las librerías

# %%
import tensorflow as tf
from tensorflow import keras
# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPooling2D, BatchNormalization
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras_preprocessing.image import ImageDataGenerator
from keras.models import load_model 
from keras.constraints import maxnorm
from tensorflow.keras.optimizers import SGD
from keras.utils import np_utils
from keras import backend as K 
K.set_image_data_format('channels_last')



# to make this notebook's output stable across runs
np.random.seed(42)

# %% [markdown]
# ## **Paso 2.** Cargar el dataset.
#
# Se utilizará el Fashion MNIST. El dataset contiene 70,000 imagenes en escala de grises de 28x28 pixeles cada una, organizadas en 10 clases.
#
# * Se utiliza keras para cargar el dataset.
# * Se realiza la separación del batch para entrenamiento y testeo, dejando 60,000 imagenes en escala de griste de de 28x28 pixeles para el set de entrenamiento.

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()

# %%
# transform to rgb as required by VGG
X_train_full=tf.image.grayscale_to_rgb(tf.expand_dims(X_train_full, axis=3)) 
X_test=tf.image.grayscale_to_rgb(tf.expand_dims(X_test, axis=3))

#resize to minimum size of (32x32
X_train_full=tf.image.resize_with_pad(X_train_full,32,32)
X_test=tf.image.resize_with_pad(X_test,32,32)

# %%
X_train_full = X_train_full / 255.0
X_test = X_test / 255.0

X_train_full = X_train_full.numpy()
X_test = X_test.numpy()

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full,y_train_full, test_size=0.1)

# %%
X_train.shape
# Out:
# (54000, 32, 32, 3)

# %% [markdown]
# ### Las etiquetas son los IDs de las clases, representados de 0 a 9.

# %%
# nombres de las clases
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# La primera imagen en el set de entrenamiento es una Coat. 
class_names[y_train_full[0]]
# Out:
# 'Ankle boot'

# %%
#Imagenes del dataset
n_rows = 4
n_cols = 5
plt.figure(figsize=(n_cols * 1.2, n_rows * 1.2))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train_full[index], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(class_names[y_train_full[index]], fontsize=12)
plt.subplots_adjust(wspace=0.2, hspace=0.5)

plt.show()

# %% [markdown]
# ### Data Augmentation
#
# Dado que el conjunto de datos se compone de pequeñas fotos de objetos, no queremos utilizar aumentos que distorsionen demasiado las imágenes, para poder conservar y utilizar las características útiles de las mismas.
#
# Los tipos de aumentos aleatorios que se utilizarán son::
#  - giro horizontal,
#  - desplazamientos del 10% en la altura y la anchura de la imagen.

# %%
# create data generator
traingen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
validgen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

#Fit the augmentation method to the data
traingen.fit(X_train)
validgen.fit(X_valid)

# prepare iterator - DA_train = data augmentation x_train, y_train
DA_train = traingen.flow(X_train, y_train, batch_size=64)
DA_valid = validgen.flow(X_valid, y_valid, batch_size=64)

# %% [markdown]
# ## **Paso 3.** Creación del modelo.
#
# ### Descargar el modelo VGG 16
#
# ImageNet es un proyecto de investigación para desarrollar una gran base de datos de imágenes con anotaciones, por ejemplo, imágenes y sus descripciones.
#
# El reto de reconocimiento visual a gran escala de ImageNet es una referencia en la clasificación y detección de categorías de objetos en cientos de categorías de objetos y millones de imágenes. El reto se ha celebrado anualmente desde 2010 hasta la actualidad, atrayendo la participación de más de cincuenta instituciones.
#
# En la tarea de clasificación, las imágenes deben clasificarse en una de las 1.000 categorías diferentes.
#
# En los últimos años se han utilizado modelos de redes neuronales convolucionales muy profundas para ganar estos retos y los resultados en las tareas han superado el rendimiento humano.
#
# [Referencia](https://machinelearningmastery.com/use-pre-trained-vgg-model-classify-objects-photographs/)
#
# <a href="https://tinyurl.com/22c8hpcq"><img src="https://miro.medium.com/max/831/1*7Ip2_SeOz_BoruHEytEMlQ.png" alt="experimentos" border="0" width="500" height="350"></a>
#
#
# [Detalles VGG Keras: ](https://keras.io/api/applications/vgg/#:~:text=The%20default%20input%20size%20for,specific%20kind%20of%20input%20preprocessing.)
#
#
# La clase VGG() toma algunos argumentos que sólo pueden interesarle si desea utilizar el modelo en su propio proyecto, por ejemplo, para el aprendizaje por transferencia.
#
#
# - include_top (True): Si se incluyen o no las capas de salida del modelo. **No se necesita esto si estás ajustando el modelo en tu propio problema.**
#
# - weights ('imagenet'): Qué pesos cargar. Se puede especificar None para no cargar pesos pre-entrenados si se está interesado en entrenar el modelo desde cero.
#
# - input_tensor (None): Una nueva capa de entrada si se tiene la intención de ajustar el modelo en nuevos datos de un tamaño diferente.
#
# - input_shape (Ninguno): El tamaño de las imágenes que se espera que tome el modelo si cambias la capa de entrada. (**3 input channels, and width and height should be no smaller than 32**)
#
# - pooling (None): El tipo de pooling a utilizar cuando se entrena un nuevo conjunto de capas de salida.
#
# - clases (1000): El número de clases (por ejemplo, el tamaño del vector de salida) para el modelo.

# %%
from keras.applications.vgg19 import VGG19

# %%
np.random.seed(42)
tf.random.set_seed(42)
keras.backend.clear_session()

# %%
VGG19_model = VGG19(include_top=False,weights='imagenet',input_shape=(32,32,3),classes=10)

# %%
## Modelo Secuencial Keras + VGG16
model = Sequential()
model.add(VGG19_model)
model.add(Flatten())
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 1, 1, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Add the Dense layers along with activation
model.add(Dense(1024,activation=('relu'),input_dim=512))
model.add(Dense(512,activation=('relu'))) 
model.add(Dense(256,activation=('relu'))) 
model.add(Dense(128,activation=('relu')))
model.add(Dense(10,activation=('softmax'))) #This is the classification layer

# %% [markdown]
# ## **Paso 4.** Compilando el modelo y entrenando el modelo.
#
#
# *   **loss**: "sparse_categorical_crossentropy", se utiliza está función dado que se cuenta con un número de etiquetas escasas (sparse) - no binarias.
# *   **optimizer** = Adam.
# *   **metrics**: Exactitud (accuracy)

# %%
model.compile(loss="sparse_categorical_crossentropy",optimizer="adam",metrics=["accuracy"])

# %% [markdown]
# ### 4.1 Callbacks - Guardar el mejor modelo durante el entrenamiento
#
# - Al utilizar datos de validación durante el entrenamiento es posible salvar el ultimo mejor modelo.
# - Actualizar la variable exp_name con el nombre del experimento a realizar.

# %%
exp_name = "EXP_12_TL_VGG19"
# Tensorflow savemodel format
best_model_name = "Trained_Models/fashion_model_" + exp_name

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint(best_model_name, save_best_only=True)
lrr= ReduceLROnPlateau(
                       monitor='val_accuracy', #Metric to be measured
                       factor=.01, #Factor by which learning rate will be reduced
                       patience=3,  #No. of epochs after which if there is no improvement in the val_acc, the learning rate is reduced
                       min_lr=1e-5) #The minimum learning rate

# %%
steps = int(X_train.shape[0] / 64)
stepsVal = int(X_valid.shape[0] / 64)

history = model.fit(DA_train, steps_per_epoch=steps, epochs=100, validation_data=(DA_valid), validation_steps=stepsVal, callbacks=[checkpoint_cb,lrr], verbose=1)
# Out:
# Epoch 1/100
# 843/843 [==============================] - 22s 21ms/step - loss: 1.3532 - accuracy: 0.4375 - val_loss: 1.0678 - val_accuracy: 0.5185
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 2/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.8450 - accuracy: 0.6572 - val_loss: 0.6899 - val_accuracy: 0.7172
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 3/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.6082 - accuracy: 0.7709 - val_loss: 0.5511 - val_accuracy: 0.8049
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 4/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.5305 - accuracy: 0.8086 - val_loss: 0.5020 - val_accuracy: 0.8327
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 5/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.4402 - accuracy: 0.8449 - val_loss: 0.4486 - val_accuracy: 0.8595
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 6/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.4208 - accuracy: 0.8551 - val_loss: 0.4009 - val_accuracy: 0.8651
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 7/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.4199 - accuracy: 0.8575 - val_loss: 0.4523 - val_accuracy: 0.8426
# Epoch 8/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.3846 - accuracy: 0.8683 - val_loss: 0.3543 - val_accuracy: 0.8732
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 9/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.3825 - accuracy: 0.8692 - val_loss: 0.3357 - val_accuracy: 0.8842
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 10/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.3595 - accuracy: 0.8801 - val_loss: 0.3453 - val_accuracy: 0.8832
# Epoch 11/100
# 843/843 [==============================] - 17s 20ms/step - loss: 0.3358 - accuracy: 0.8899 - val_loss: 0.3204 - val_accuracy: 0.8884
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 12/100
# 843/843 [==============================] - 18s 22ms/step - loss: 0.3040 - accuracy: 0.8966 - val_loss: 0.3038 - val_accuracy: 0.8948
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 13/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.3977 - accuracy: 0.8656 - val_loss: 0.4100 - val_accuracy: 0.8693
# Epoch 14/100
# 843/843 [==============================] - 17s 20ms/step - loss: 0.3092 - accuracy: 0.8944 - val_loss: 0.3067 - val_accuracy: 0.8938
# Epoch 15/100
# 843/843 [==============================] - 17s 20ms/step - loss: 0.3110 - accuracy: 0.8931 - val_loss: 0.3114 - val_accuracy: 0.8972
# Epoch 16/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.3067 - accuracy: 0.8953 - val_loss: 0.3110 - val_accuracy: 0.8943
# Epoch 17/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.2872 - accuracy: 0.9025 - val_loss: 0.3023 - val_accuracy: 0.8967
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 18/100
# 843/843 [==============================] - 20s 23ms/step - loss: 0.2839 - accuracy: 0.9027 - val_loss: 0.3232 - val_accuracy: 0.8881
# Epoch 19/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.2522 - accuracy: 0.9111 - val_loss: 0.2651 - val_accuracy: 0.9061
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 20/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.2368 - accuracy: 0.9166 - val_loss: 0.2581 - val_accuracy: 0.9096
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 21/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.2288 - accuracy: 0.9186 - val_loss: 0.2543 - val_accuracy: 0.9110
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 22/100
# 843/843 [==============================] - 20s 24ms/step - loss: 0.2241 - accuracy: 0.9202 - val_loss: 0.2491 - val_accuracy: 0.9133
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 23/100
# 843/843 [==============================] - 20s 24ms/step - loss: 0.2229 - accuracy: 0.9207 - val_loss: 0.2461 - val_accuracy: 0.9128
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 24/100
# 843/843 [==============================] - 21s 25ms/step - loss: 0.2187 - accuracy: 0.9226 - val_loss: 0.2452 - val_accuracy: 0.9135
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 25/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.2159 - accuracy: 0.9233 - val_loss: 0.2436 - val_accuracy: 0.9133
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 26/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.2112 - accuracy: 0.9251 - val_loss: 0.2367 - val_accuracy: 0.9173
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 27/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.2106 - accuracy: 0.9252 - val_loss: 0.2300 - val_accuracy: 0.9165
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 28/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.2091 - accuracy: 0.9260 - val_loss: 0.2367 - val_accuracy: 0.9180
# Epoch 29/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.2078 - accuracy: 0.9260 - val_loss: 0.2368 - val_accuracy: 0.9163
# Epoch 30/100
# 843/843 [==============================] - 17s 20ms/step - loss: 0.2049 - accuracy: 0.9267 - val_loss: 0.2389 - val_accuracy: 0.9192
# Epoch 31/100
# 843/843 [==============================] - 17s 21ms/step - loss: 0.2038 - accuracy: 0.9261 - val_loss: 0.2271 - val_accuracy: 0.9219
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 32/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.2031 - accuracy: 0.9291 - val_loss: 0.2314 - val_accuracy: 0.9215
# Epoch 33/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.2010 - accuracy: 0.9286 - val_loss: 0.2357 - val_accuracy: 0.9189
# Epoch 34/100
# 843/843 [==============================] - 17s 20ms/step - loss: 0.1986 - accuracy: 0.9289 - val_loss: 0.2339 - val_accuracy: 0.9157
# Epoch 35/100
# 843/843 [==============================] - 17s 20ms/step - loss: 0.2006 - accuracy: 0.9286 - val_loss: 0.2251 - val_accuracy: 0.9195
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 36/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.1984 - accuracy: 0.9294 - val_loss: 0.2340 - val_accuracy: 0.9140
# Epoch 37/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.1975 - accuracy: 0.9292 - val_loss: 0.2248 - val_accuracy: 0.9204
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 38/100
# 843/843 [==============================] - 20s 23ms/step - loss: 0.1981 - accuracy: 0.9302 - val_loss: 0.2268 - val_accuracy: 0.9231
# Epoch 39/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.1948 - accuracy: 0.9301 - val_loss: 0.2310 - val_accuracy: 0.9152
# Epoch 40/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.1947 - accuracy: 0.9298 - val_loss: 0.2232 - val_accuracy: 0.9200
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 41/100
# 843/843 [==============================] - 20s 23ms/step - loss: 0.1941 - accuracy: 0.9299 - val_loss: 0.2278 - val_accuracy: 0.9200
# Epoch 42/100
# 843/843 [==============================] - 17s 21ms/step - loss: 0.1919 - accuracy: 0.9318 - val_loss: 0.2277 - val_accuracy: 0.9197
# Epoch 43/100
# 843/843 [==============================] - 17s 20ms/step - loss: 0.1923 - accuracy: 0.9311 - val_loss: 0.2301 - val_accuracy: 0.9192
# Epoch 44/100
# 843/843 [==============================] - 17s 21ms/step - loss: 0.1939 - accuracy: 0.9312 - val_loss: 0.2297 - val_accuracy: 0.9170
# Epoch 45/100
# 843/843 [==============================] - 18s 22ms/step - loss: 0.1914 - accuracy: 0.9311 - val_loss: 0.2250 - val_accuracy: 0.9197
# Epoch 46/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.1893 - accuracy: 0.9318 - val_loss: 0.2302 - val_accuracy: 0.9204
# Epoch 47/100
# 843/843 [==============================] - 18s 22ms/step - loss: 0.1896 - accuracy: 0.9318 - val_loss: 0.2209 - val_accuracy: 0.9202
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 48/100
# 843/843 [==============================] - 22s 26ms/step - loss: 0.1899 - accuracy: 0.9324 - val_loss: 0.2229 - val_accuracy: 0.9199
# Epoch 49/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.1876 - accuracy: 0.9333 - val_loss: 0.2319 - val_accuracy: 0.9209
# Epoch 50/100
# 843/843 [==============================] - 20s 24ms/step - loss: 0.1860 - accuracy: 0.9329 - val_loss: 0.2227 - val_accuracy: 0.9234
# Epoch 51/100
# 843/843 [==============================] - 20s 24ms/step - loss: 0.1856 - accuracy: 0.9330 - val_loss: 0.2223 - val_accuracy: 0.9242
# Epoch 52/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.1863 - accuracy: 0.9329 - val_loss: 0.2181 - val_accuracy: 0.9222
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 53/100
# 843/843 [==============================] - 23s 27ms/step - loss: 0.1854 - accuracy: 0.9334 - val_loss: 0.2248 - val_accuracy: 0.9246
# Epoch 54/100
# 843/843 [==============================] - 18s 22ms/step - loss: 0.1864 - accuracy: 0.9338 - val_loss: 0.2258 - val_accuracy: 0.9217
# Epoch 55/100
# 843/843 [==============================] - 18s 22ms/step - loss: 0.1851 - accuracy: 0.9334 - val_loss: 0.2236 - val_accuracy: 0.9212
# Epoch 56/100
# 843/843 [==============================] - 20s 24ms/step - loss: 0.1854 - accuracy: 0.9334 - val_loss: 0.2256 - val_accuracy: 0.9200
# Epoch 57/100
# 843/843 [==============================] - 18s 22ms/step - loss: 0.1840 - accuracy: 0.9347 - val_loss: 0.2264 - val_accuracy: 0.9204
# Epoch 58/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.1850 - accuracy: 0.9345 - val_loss: 0.2101 - val_accuracy: 0.9247
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 59/100
# 843/843 [==============================] - 21s 24ms/step - loss: 0.1825 - accuracy: 0.9350 - val_loss: 0.2177 - val_accuracy: 0.9231
# Epoch 60/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.1820 - accuracy: 0.9351 - val_loss: 0.2219 - val_accuracy: 0.9229
# Epoch 61/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.1817 - accuracy: 0.9354 - val_loss: 0.2278 - val_accuracy: 0.9204
# Epoch 62/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.1818 - accuracy: 0.9346 - val_loss: 0.2205 - val_accuracy: 0.9219
# Epoch 63/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.1812 - accuracy: 0.9344 - val_loss: 0.2185 - val_accuracy: 0.9242
# Epoch 64/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.1801 - accuracy: 0.9349 - val_loss: 0.2211 - val_accuracy: 0.9224
# Epoch 65/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.1798 - accuracy: 0.9351 - val_loss: 0.2191 - val_accuracy: 0.9227
# Epoch 66/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.1793 - accuracy: 0.9357 - val_loss: 0.2178 - val_accuracy: 0.9225
# Epoch 67/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.1793 - accuracy: 0.9353 - val_loss: 0.2099 - val_accuracy: 0.9217
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 68/100
# 843/843 [==============================] - 20s 24ms/step - loss: 0.1799 - accuracy: 0.9353 - val_loss: 0.2206 - val_accuracy: 0.9205
# Epoch 69/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.1763 - accuracy: 0.9370 - val_loss: 0.2224 - val_accuracy: 0.9215
# Epoch 70/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.1777 - accuracy: 0.9358 - val_loss: 0.2163 - val_accuracy: 0.9256
# Epoch 71/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.1771 - accuracy: 0.9371 - val_loss: 0.2212 - val_accuracy: 0.9224
# Epoch 72/100
# 843/843 [==============================] - 18s 22ms/step - loss: 0.1768 - accuracy: 0.9368 - val_loss: 0.2177 - val_accuracy: 0.9249
# Epoch 73/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.1769 - accuracy: 0.9373 - val_loss: 0.2163 - val_accuracy: 0.9222
# Epoch 74/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.1754 - accuracy: 0.9365 - val_loss: 0.2179 - val_accuracy: 0.9207
# Epoch 75/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.1742 - accuracy: 0.9368 - val_loss: 0.2174 - val_accuracy: 0.9217
# Epoch 76/100
# 843/843 [==============================] - 18s 22ms/step - loss: 0.1750 - accuracy: 0.9367 - val_loss: 0.2192 - val_accuracy: 0.9246
# Epoch 77/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.1770 - accuracy: 0.9365 - val_loss: 0.2129 - val_accuracy: 0.9242
# Epoch 78/100
# 843/843 [==============================] - 20s 23ms/step - loss: 0.1737 - accuracy: 0.9383 - val_loss: 0.2149 - val_accuracy: 0.9242
# Epoch 79/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.1750 - accuracy: 0.9370 - val_loss: 0.2170 - val_accuracy: 0.9210
# Epoch 80/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.1748 - accuracy: 0.9380 - val_loss: 0.2215 - val_accuracy: 0.9239
# Epoch 81/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.1744 - accuracy: 0.9383 - val_loss: 0.2151 - val_accuracy: 0.9210
# Epoch 82/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.1744 - accuracy: 0.9369 - val_loss: 0.2149 - val_accuracy: 0.9217
# Epoch 83/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.1731 - accuracy: 0.9378 - val_loss: 0.2168 - val_accuracy: 0.9209
# Epoch 84/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.1733 - accuracy: 0.9375 - val_loss: 0.2193 - val_accuracy: 0.9241
# Epoch 85/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.1719 - accuracy: 0.9377 - val_loss: 0.2085 - val_accuracy: 0.9273
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_12_TL_VGG19\assets
# Epoch 86/100
# 843/843 [==============================] - 23s 27ms/step - loss: 0.1723 - accuracy: 0.9377 - val_loss: 0.2167 - val_accuracy: 0.9220
# Epoch 87/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.1714 - accuracy: 0.9380 - val_loss: 0.2095 - val_accuracy: 0.9261
# Epoch 88/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.1692 - accuracy: 0.9397 - val_loss: 0.2142 - val_accuracy: 0.9237
# Epoch 89/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.1704 - accuracy: 0.9391 - val_loss: 0.2150 - val_accuracy: 0.9259
# Epoch 90/100
# 843/843 [==============================] - 18s 22ms/step - loss: 0.1708 - accuracy: 0.9383 - val_loss: 0.2184 - val_accuracy: 0.9207
# Epoch 91/100
# 843/843 [==============================] - 18s 22ms/step - loss: 0.1702 - accuracy: 0.9392 - val_loss: 0.2149 - val_accuracy: 0.9237
# Epoch 92/100
# 843/843 [==============================] - 18s 22ms/step - loss: 0.1681 - accuracy: 0.9392 - val_loss: 0.2186 - val_accuracy: 0.9244
# Epoch 93/100
# 843/843 [==============================] - 19s 23ms/step - loss: 0.1677 - accuracy: 0.9386 - val_loss: 0.2178 - val_accuracy: 0.9217
# Epoch 94/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.1702 - accuracy: 0.9383 - val_loss: 0.2136 - val_accuracy: 0.9271
# Epoch 95/100
# 843/843 [==============================] - 20s 23ms/step - loss: 0.1665 - accuracy: 0.9408 - val_loss: 0.2110 - val_accuracy: 0.9244
# Epoch 96/100
# 843/843 [==============================] - 19s 22ms/step - loss: 0.1680 - accuracy: 0.9390 - val_loss: 0.2191 - val_accuracy: 0.9239
# Epoch 97/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.1673 - accuracy: 0.9407 - val_loss: 0.2187 - val_accuracy: 0.9229
# Epoch 98/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.1663 - accuracy: 0.9392 - val_loss: 0.2106 - val_accuracy: 0.9267
# Epoch 99/100
# 843/843 [==============================] - 18s 21ms/step - loss: 0.1661 - accuracy: 0.9397 - val_loss: 0.2156 - val_accuracy: 0.9244
# Epoch 100/100
# 843/843 [==============================] - 17s 21ms/step - loss: 0.1645 - accuracy: 0.9415 - val_loss: 0.2099 - val_accuracy: 0.9242

# %%
# se utiliza pandas para visualizar la información almacenada en el diccionario de historia de entrenamiento y graficarla. 
import pandas as pd

pd.DataFrame(history.history).plot(figsize=(6, 4))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# ## **Paso 5.** Evaluación del modelo.
# Se evalua el modelo con el conjunto de datos de prueba.
#
# - X_train: Conjunto de datos de entrenamiento.
# - y_train: Etiquetas de los datos de entrenamiento.
# - X_valid: Conjunto de datos de validación.
# - y_valid: Etiquetas de los datos de validación.
# - X_test: Conjunto de datos de prueba.
# - y_test: Etiquetas de los datos de prueba.

# %%
model = load_model(best_model_name)

# %%
scores_train = model.evaluate(X_train, y_train)
scores_valid = model.evaluate(X_valid, y_valid)
scores_test = model.evaluate(X_test, y_test)
# Out:
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1666 - accuracy: 0.9397
# 188/188 [==============================] - 1s 5ms/step - loss: 0.2066 - accuracy: 0.9267
# 313/313 [==============================] - 2s 5ms/step - loss: 0.2217 - accuracy: 0.9231

# %%
print('train loss:', round(scores_train[0]*100,2), '%')
print('valid loss:', round(scores_valid[0]*100,2), '%')
print('test loss:', round(scores_test[0]*100,2), '%')
print("\n")
print('train accuracy:', round(scores_train[1]*100,2), '%')
print('valid accuracy:', round(scores_valid[1]*100,2), '%')
print('test accuracy:', round(scores_test[1]*100,2), '%')
# Out:
# train loss: 16.66 %
# valid loss: 20.66 %
# test loss: 22.17 %
#
#
# train accuracy: 93.97 %
# valid accuracy: 92.67 %
# test accuracy: 92.31 %

# %% [markdown]
# ## **Paso 6.** Usando el modelo para hacer predicciones.
#
# Se toman 5 instancias del set de prueba para hacer la predicción. y se imprime la matriz de probabilidad para cada una de las instancias.

# %%
X_new = X_test[10:15]
y_proba = model.predict(X_new)

# %%
classes_x = np.argmax(y_proba,axis=1)

# %%
# Valores predichos
np.array(class_names)[classes_x]
# Out:
# array(['Coat', 'Sandal', 'Sneaker', 'Dress', 'Coat'], dtype='<U11')

# %%
y_new = y_test[10:15]
plt.figure(figsize=(6, 2))
for index, image in enumerate(X_new):
    plt.subplot(1, 5, index + 1)
    plt.imshow(image, cmap="binary", interpolation="nearest")
    plt.axis('off')
    plt.title(class_names[y_new[index]], fontsize=10)
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()
