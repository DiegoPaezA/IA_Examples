# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://is.gd/PknrJU" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# # Transfer Learning + CNN + CIFAR-10
#
# Se utilizará una **red neuronal convolucional** para clasificar imágenes de 32x32x3 (RGB) en 10 clases.
#
# El conjunto de datos CIFAR-10 consta de 60000 imágenes en color de 32x32 en 10 clases, con 6000 imágenes por clase. Hay 50000 imágenes de entrenamiento y 10000 de prueba.
#
#
# Referencias: https://www.cs.toronto.edu/~kriz/cifar.html
#
# <a href="https://imgbb.com/"><img src="https://i.ibb.co/SXtPQzj/CIFAR10.png" alt="CIFAR10" border="0"></a>
#
# ### **Transfer Learning**
#
# El aprendizaje por transferencia es un método de aprendizaje automático en el que **un modelo desarrollado para una tarea se reutiliza** como punto de partida para un modelo en una segunda tarea.
#
# Es un enfoque popular en el aprendizaje profundo, en el que se utilizan modelos preentrenados como punto de partida en tareas de visión por ordenador y procesamiento del lenguaje natural, dados los enormes recursos de computación y tiempo necesarios para desarrollar modelos de redes neuronales en estos problemas y por los enormes saltos de habilidad que proporcionan en problemas relacionados.
#
# <a href="https://tinyurl.com/yauxq2ap"><img src="https://machinelearningmastery.com/wp-content/uploads/2017/09/Three-ways-in-which-transfer-might-improve-learning.png" alt="experimentos" border="0" width="500" height="250"></a>

# %% [markdown]
# ## **Paso 1.** Importar las librerías necesarias

# %%
import tensorflow as tf
from tensorflow import keras
# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPooling2D, BatchNormalization
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras_preprocessing.image import ImageDataGenerator
from keras.models import load_model 
from keras.constraints import maxnorm
from tensorflow.keras.optimizers import SGD
from keras.utils import np_utils
from keras import backend as K 
K.set_image_data_format('channels_last')

# to make this notebook's output stable across runs
np.random.seed(42)

# %% [markdown]
# ## **Paso 2.** Cargar el dataset
# Se cargan los datos de entrenamiento y prueba y se escala la intensidad de los píxeles en el rango de 0-1 y se convierten en flotantes, dividiéndolos por 255.

# %%
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.cifar10.load_data()
#normalizing inputs from 0-255 to 0.0-1.0 
X_train_full = X_train_full.astype('float32') 
X_test = X_test.astype('float32') 
X_train_full = X_train_full / 255.0 
X_test = X_test / 255.0

# %%
X_train_full.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# Se Divide el conjunto de entrenamiento completo en un subconjunto de validación y un subconjunto de entrenamiento (más pequeño).
#
# ![Split Data](https://806230.smushcdn.com/1739487/wp-content/uploads/2021/04/train-and-test-1-min-1.png )

# %%
from keras.utils.np_utils import to_categorical

# %%
y_train_full = to_categorical(y_train_full, num_classes = 10)
y_test = to_categorical(y_test, num_classes = 10)

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full,y_train_full, test_size=0.2)

# %% [markdown]
# ### **Paso 2.1.** Visualizar las imágenes del conjunto de datos

# %%
# initialize the label names for the CIFAR-10 dataset
class_names = ["airplane", "automobile", "bird", "cat", "deer",
	"dog", "frog", "horse", "ship", "truck"]
print(class_names[np.argmax(y_train[0])])
# Out:
# frog

# %%
n_rows = 4
n_cols = 5
plt.figure(figsize=(n_cols * 1.2, n_rows * 1.2))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(class_names[np.argmax(y_train[index])], fontsize=12)
plt.subplots_adjust(wspace=0.2, hspace=0.5)

plt.show()

# %% [markdown]
# ### Data Augmentation
#
# Dado que el conjunto de datos se compone de pequeñas fotos de objetos, no queremos utilizar aumentos que distorsionen demasiado las imágenes, para poder conservar y utilizar las características útiles de las mismas.
#
# Los tipos de aumentos aleatorios que se utilizarán son::
#  - giro horizontal,
#  - desplazamientos del 10% en la altura y la anchura de la imagen.

# %%
# create data generator
traingen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
validgen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

#Fit the augmentation method to the data
traingen.fit(X_train)
validgen.fit(X_valid)

# prepare iterator - DA_train = data augmentation x_train, y_train
DA_train = traingen.flow(X_train, y_train, batch_size=64)
DA_valid = validgen.flow(X_valid, y_valid, batch_size=64)

# %% [markdown]
# ## **Paso 3.** Creación del modelo.
#
# ### Descargar el modelo VGG 16
#
# ImageNet es un proyecto de investigación para desarrollar una gran base de datos de imágenes con anotaciones, por ejemplo, imágenes y sus descripciones.
#
# El reto de reconocimiento visual a gran escala de ImageNet es una referencia en la clasificación y detección de categorías de objetos en cientos de categorías de objetos y millones de imágenes. El reto se ha celebrado anualmente desde 2010 hasta la actualidad, atrayendo la participación de más de cincuenta instituciones.
#
# En la tarea de clasificación, las imágenes deben clasificarse en una de las 1.000 categorías diferentes.
#
# En los últimos años se han utilizado modelos de redes neuronales convolucionales muy profundas para ganar estos retos y los resultados en las tareas han superado el rendimiento humano.
#
# [Referencia](https://machinelearningmastery.com/use-pre-trained-vgg-model-classify-objects-photographs/)
#
# <a href="https://tinyurl.com/22c8hpcq"><img src="https://miro.medium.com/max/831/1*7Ip2_SeOz_BoruHEytEMlQ.png" alt="experimentos" border="0" width="500" height="350"></a>
#
#
# [Detalles VGG Keras: ](https://keras.io/api/applications/vgg/#:~:text=The%20default%20input%20size%20for,specific%20kind%20of%20input%20preprocessing.)
#
#
# La clase VGG() toma algunos argumentos que sólo pueden interesarle si desea utilizar el modelo en su propio proyecto, por ejemplo, para el aprendizaje por transferencia.
#
#
# - include_top (True): Si se incluyen o no las capas de salida del modelo. **No se necesita esto si estás ajustando el modelo en tu propio problema.**
#
# - weights ('imagenet'): Qué pesos cargar. Se puede especificar None para no cargar pesos pre-entrenados si se está interesado en entrenar el modelo desde cero.
#
# - input_tensor (None): Una nueva capa de entrada si se tiene la intención de ajustar el modelo en nuevos datos de un tamaño diferente.
#
# - input_shape (Ninguno): El tamaño de las imágenes que se espera que tome el modelo si cambias la capa de entrada. (**3 input channels, and width and height should be no smaller than 32**)
#
# - pooling (None): El tipo de pooling a utilizar cuando se entrena un nuevo conjunto de capas de salida.
#
# - clases (1000): El número de clases (por ejemplo, el tamaño del vector de salida) para el modelo.

# %%
from keras.applications.vgg16 import VGG16

# %%
np.random.seed(42)
tf.random.set_seed(42)
keras.backend.clear_session()

# %%
VGG16_model = VGG16(include_top=False,weights='imagenet',input_shape=(32,32,3),classes=y_train.shape[1])

# %%
## Modelo Secuencial Keras + VGG16
model = Sequential()
model.add(VGG16_model)
model.add(Flatten())
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 1, 1, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Add the Dense layers along with activation
model.add(Dense(1024,activation=('relu'),input_dim=512))
model.add(Dense(512,activation=('relu'))) 
model.add(Dense(256,activation=('relu'))) 
model.add(Dense(128,activation=('relu')))
model.add(Dense(10,activation=('softmax'))) #This is the classification layer

# %% [markdown]
# ## **Paso 4.** Compilando el modelo y entrenando el modelo.
#
#
# *   **loss**: "sparse_categorical_crossentropy", se utiliza está función dado que se cuenta con un número de etiquetas escasas (sparse) - no binarias.
# *   **optimizer** = Adam.
# *   **metrics**: Exactitud (accuracy)

# %%
lr=.001
sgd=SGD(learning_rate=lr,momentum=.9,nesterov=False)

# %%
# Compile model 
model.compile(loss="categorical_crossentropy",optimizer=sgd,metrics=["accuracy"])

# %% [markdown]
# ### 4.1 Callbacks - Guardar el mejor modelo durante el entrenamiento
#
# - Al utilizar datos de validación durante el entrenamiento es posible salvar el ultimo mejor modelo.
# - Actualizar la variable exp_name con el nombre del experimento a realizar.

# %%
exp_name = "EXP_11_TL_VGG16"
# Tensorflow savemodel format
best_model_name = "Trained_Models/cifar10_model_" + exp_name

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint(best_model_name, save_best_only=True)
lrr= ReduceLROnPlateau(
                       monitor='val_accuracy', #Metric to be measured
                       factor=.01, #Factor by which learning rate will be reduced
                       patience=3,  #No. of epochs after which if there is no improvement in the val_acc, the learning rate is reduced
                       min_lr=1e-5) #The minimum learning rate

# %%
steps = int(X_train.shape[0] / 64)
stepsVal = int(X_valid.shape[0] / 64)

history = model.fit(DA_train, steps_per_epoch=steps, epochs=100, validation_data=(DA_valid), validation_steps=stepsVal, callbacks=[checkpoint_cb,lrr], verbose=1) 
#history = model.fit(X_train, y_train, batch_size=64, epochs=100, validation_data=(X_valid, y_valid), callbacks=[checkpoint_cb,lrr], verbose=1)
# Out:
# Epoch 1/100
# 625/625 [==============================] - 15s 20ms/step - loss: 1.1960 - accuracy: 0.5768 - val_loss: 0.8741 - val_accuracy: 0.6886
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG16\assets
# Epoch 2/100
# 625/625 [==============================] - 12s 20ms/step - loss: 0.7493 - accuracy: 0.7388 - val_loss: 0.7160 - val_accuracy: 0.7488
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG16\assets
# Epoch 3/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.6167 - accuracy: 0.7842 - val_loss: 0.5969 - val_accuracy: 0.7954
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG16\assets
# Epoch 4/100
# 625/625 [==============================] - 13s 20ms/step - loss: 0.5317 - accuracy: 0.8139 - val_loss: 0.5375 - val_accuracy: 0.8130
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG16\assets
# Epoch 5/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.4872 - accuracy: 0.8311 - val_loss: 0.5856 - val_accuracy: 0.8064
# Epoch 6/100
# 625/625 [==============================] - 12s 20ms/step - loss: 0.4419 - accuracy: 0.8463 - val_loss: 0.5022 - val_accuracy: 0.8293
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG16\assets
# Epoch 7/100
# 625/625 [==============================] - 12s 19ms/step - loss: 0.4091 - accuracy: 0.8546 - val_loss: 0.4996 - val_accuracy: 0.8299
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG16\assets
# Epoch 8/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.3691 - accuracy: 0.8712 - val_loss: 0.4764 - val_accuracy: 0.8339
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG16\assets
# Epoch 9/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.3423 - accuracy: 0.8788 - val_loss: 0.4869 - val_accuracy: 0.8407
# Epoch 10/100
# 625/625 [==============================] - 12s 20ms/step - loss: 0.3229 - accuracy: 0.8860 - val_loss: 0.4421 - val_accuracy: 0.8522
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG16\assets
# Epoch 11/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.2937 - accuracy: 0.8964 - val_loss: 0.4537 - val_accuracy: 0.8498
# Epoch 12/100
# 625/625 [==============================] - 12s 20ms/step - loss: 0.2759 - accuracy: 0.9034 - val_loss: 0.4508 - val_accuracy: 0.8520
# Epoch 13/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.2575 - accuracy: 0.9097 - val_loss: 0.4481 - val_accuracy: 0.8559
# Epoch 14/100
# 625/625 [==============================] - 12s 20ms/step - loss: 0.2358 - accuracy: 0.9164 - val_loss: 0.4691 - val_accuracy: 0.8521
# Epoch 15/100
# 625/625 [==============================] - 12s 20ms/step - loss: 0.2143 - accuracy: 0.9255 - val_loss: 0.4637 - val_accuracy: 0.8559
# Epoch 16/100
# 625/625 [==============================] - 12s 20ms/step - loss: 0.2009 - accuracy: 0.9301 - val_loss: 0.4767 - val_accuracy: 0.8535
# Epoch 17/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.1785 - accuracy: 0.9387 - val_loss: 0.4035 - val_accuracy: 0.8701
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG16\assets
# Epoch 18/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.1347 - accuracy: 0.9553 - val_loss: 0.4105 - val_accuracy: 0.8746
# Epoch 19/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.1265 - accuracy: 0.9582 - val_loss: 0.4050 - val_accuracy: 0.8724
# Epoch 20/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.1228 - accuracy: 0.9603 - val_loss: 0.4043 - val_accuracy: 0.8763
# Epoch 21/100
# 625/625 [==============================] - 13s 20ms/step - loss: 0.1215 - accuracy: 0.9589 - val_loss: 0.4031 - val_accuracy: 0.8760
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG16\assets
# Epoch 22/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.1184 - accuracy: 0.9609 - val_loss: 0.4055 - val_accuracy: 0.8765
# Epoch 23/100
# 625/625 [==============================] - 13s 20ms/step - loss: 0.1158 - accuracy: 0.9619 - val_loss: 0.4044 - val_accuracy: 0.8782
# Epoch 24/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.1151 - accuracy: 0.9624 - val_loss: 0.4122 - val_accuracy: 0.8747
# Epoch 25/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.1126 - accuracy: 0.9624 - val_loss: 0.4010 - val_accuracy: 0.8776
# INFO:tensorflow:Assets written to: Trained_Models\fashion_model_EXP_11_Cifar_TL_VGG16\assets
# Epoch 26/100
# 625/625 [==============================] - 16s 25ms/step - loss: 0.1134 - accuracy: 0.9617 - val_loss: 0.4091 - val_accuracy: 0.8756
# Epoch 27/100
# 625/625 [==============================] - 13s 20ms/step - loss: 0.1077 - accuracy: 0.9648 - val_loss: 0.4127 - val_accuracy: 0.8767
# Epoch 28/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.1096 - accuracy: 0.9639 - val_loss: 0.4050 - val_accuracy: 0.8760
# Epoch 29/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.1072 - accuracy: 0.9650 - val_loss: 0.4152 - val_accuracy: 0.8765
# Epoch 30/100
# 625/625 [==============================] - 15s 23ms/step - loss: 0.1067 - accuracy: 0.9651 - val_loss: 0.4096 - val_accuracy: 0.8757
# Epoch 31/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.1060 - accuracy: 0.9650 - val_loss: 0.4118 - val_accuracy: 0.8794
# Epoch 32/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.1045 - accuracy: 0.9657 - val_loss: 0.4101 - val_accuracy: 0.8781
# Epoch 33/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.1058 - accuracy: 0.9650 - val_loss: 0.4144 - val_accuracy: 0.8779
# Epoch 34/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.1055 - accuracy: 0.9647 - val_loss: 0.4131 - val_accuracy: 0.8788
# Epoch 35/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.1015 - accuracy: 0.9668 - val_loss: 0.4144 - val_accuracy: 0.8794
# Epoch 36/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.1033 - accuracy: 0.9660 - val_loss: 0.4099 - val_accuracy: 0.8802
# Epoch 37/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.1022 - accuracy: 0.9657 - val_loss: 0.4109 - val_accuracy: 0.8761
# Epoch 38/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.1029 - accuracy: 0.9668 - val_loss: 0.4128 - val_accuracy: 0.8793
# Epoch 39/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0987 - accuracy: 0.9668 - val_loss: 0.4197 - val_accuracy: 0.8762
# Epoch 40/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0986 - accuracy: 0.9674 - val_loss: 0.4189 - val_accuracy: 0.8769
# Epoch 41/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0985 - accuracy: 0.9677 - val_loss: 0.4150 - val_accuracy: 0.8800
# Epoch 42/100
# 625/625 [==============================] - 13s 22ms/step - loss: 0.0991 - accuracy: 0.9665 - val_loss: 0.4111 - val_accuracy: 0.8792
# Epoch 43/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0999 - accuracy: 0.9671 - val_loss: 0.4169 - val_accuracy: 0.8765
# Epoch 44/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0958 - accuracy: 0.9682 - val_loss: 0.4162 - val_accuracy: 0.8799
# Epoch 45/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0957 - accuracy: 0.9691 - val_loss: 0.4194 - val_accuracy: 0.8770
# Epoch 46/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0965 - accuracy: 0.9676 - val_loss: 0.4208 - val_accuracy: 0.8781
# Epoch 47/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0974 - accuracy: 0.9679 - val_loss: 0.4211 - val_accuracy: 0.8803
# Epoch 48/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0954 - accuracy: 0.9685 - val_loss: 0.4248 - val_accuracy: 0.8770
# Epoch 49/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0960 - accuracy: 0.9682 - val_loss: 0.4233 - val_accuracy: 0.8791
# Epoch 50/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0953 - accuracy: 0.9683 - val_loss: 0.4241 - val_accuracy: 0.8782
# Epoch 51/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0934 - accuracy: 0.9694 - val_loss: 0.4152 - val_accuracy: 0.8783
# Epoch 52/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0951 - accuracy: 0.9678 - val_loss: 0.4198 - val_accuracy: 0.8774
# Epoch 53/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0916 - accuracy: 0.9695 - val_loss: 0.4140 - val_accuracy: 0.8791
# Epoch 54/100
# 625/625 [==============================] - 15s 25ms/step - loss: 0.0931 - accuracy: 0.9694 - val_loss: 0.4280 - val_accuracy: 0.8757
# Epoch 55/100
# 625/625 [==============================] - 15s 24ms/step - loss: 0.0925 - accuracy: 0.9689 - val_loss: 0.4290 - val_accuracy: 0.8745
# Epoch 56/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0915 - accuracy: 0.9691 - val_loss: 0.4370 - val_accuracy: 0.8767
# Epoch 57/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0904 - accuracy: 0.9700 - val_loss: 0.4247 - val_accuracy: 0.8778
# Epoch 58/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0906 - accuracy: 0.9708 - val_loss: 0.4216 - val_accuracy: 0.8803
# Epoch 59/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0872 - accuracy: 0.9714 - val_loss: 0.4274 - val_accuracy: 0.8798
# Epoch 60/100
# 625/625 [==============================] - 15s 24ms/step - loss: 0.0912 - accuracy: 0.9700 - val_loss: 0.4249 - val_accuracy: 0.8791
# Epoch 61/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0895 - accuracy: 0.9712 - val_loss: 0.4268 - val_accuracy: 0.8785
# Epoch 62/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0895 - accuracy: 0.9700 - val_loss: 0.4271 - val_accuracy: 0.8772
# Epoch 63/100
# 625/625 [==============================] - 13s 20ms/step - loss: 0.0897 - accuracy: 0.9706 - val_loss: 0.4354 - val_accuracy: 0.8784
# Epoch 64/100
# 625/625 [==============================] - 13s 20ms/step - loss: 0.0900 - accuracy: 0.9692 - val_loss: 0.4304 - val_accuracy: 0.8783
# Epoch 65/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0881 - accuracy: 0.9714 - val_loss: 0.4237 - val_accuracy: 0.8803
# Epoch 66/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0888 - accuracy: 0.9707 - val_loss: 0.4335 - val_accuracy: 0.8759
# Epoch 67/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0860 - accuracy: 0.9720 - val_loss: 0.4282 - val_accuracy: 0.8759
# Epoch 68/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0854 - accuracy: 0.9714 - val_loss: 0.4143 - val_accuracy: 0.8806
# Epoch 69/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0855 - accuracy: 0.9726 - val_loss: 0.4311 - val_accuracy: 0.8807
# Epoch 70/100
# 625/625 [==============================] - 13s 20ms/step - loss: 0.0844 - accuracy: 0.9724 - val_loss: 0.4310 - val_accuracy: 0.8788
# Epoch 71/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0841 - accuracy: 0.9733 - val_loss: 0.4319 - val_accuracy: 0.8770
# Epoch 72/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0853 - accuracy: 0.9718 - val_loss: 0.4223 - val_accuracy: 0.8794
# Epoch 73/100
# 625/625 [==============================] - 13s 20ms/step - loss: 0.0836 - accuracy: 0.9723 - val_loss: 0.4373 - val_accuracy: 0.8773
# Epoch 74/100
# 625/625 [==============================] - 13s 20ms/step - loss: 0.0870 - accuracy: 0.9714 - val_loss: 0.4356 - val_accuracy: 0.8783
# Epoch 75/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0843 - accuracy: 0.9718 - val_loss: 0.4382 - val_accuracy: 0.8775
# Epoch 76/100
# 625/625 [==============================] - 13s 20ms/step - loss: 0.0859 - accuracy: 0.9716 - val_loss: 0.4358 - val_accuracy: 0.8789
# Epoch 77/100
# 625/625 [==============================] - 15s 25ms/step - loss: 0.0848 - accuracy: 0.9728 - val_loss: 0.4310 - val_accuracy: 0.8783
# Epoch 78/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0869 - accuracy: 0.9718 - val_loss: 0.4477 - val_accuracy: 0.8760
# Epoch 79/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0827 - accuracy: 0.9731 - val_loss: 0.4292 - val_accuracy: 0.8802
# Epoch 80/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0841 - accuracy: 0.9722 - val_loss: 0.4442 - val_accuracy: 0.8782
# Epoch 81/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0832 - accuracy: 0.9726 - val_loss: 0.4238 - val_accuracy: 0.8818
# Epoch 82/100
# 625/625 [==============================] - 13s 20ms/step - loss: 0.0833 - accuracy: 0.9719 - val_loss: 0.4358 - val_accuracy: 0.8763
# Epoch 83/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0809 - accuracy: 0.9738 - val_loss: 0.4297 - val_accuracy: 0.8803
# Epoch 84/100
# 625/625 [==============================] - 12s 20ms/step - loss: 0.0816 - accuracy: 0.9725 - val_loss: 0.4392 - val_accuracy: 0.8757
# Epoch 85/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0814 - accuracy: 0.9732 - val_loss: 0.4426 - val_accuracy: 0.8786
# Epoch 86/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0816 - accuracy: 0.9735 - val_loss: 0.4399 - val_accuracy: 0.8792
# Epoch 87/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0795 - accuracy: 0.9732 - val_loss: 0.4357 - val_accuracy: 0.8772
# Epoch 88/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0810 - accuracy: 0.9733 - val_loss: 0.4350 - val_accuracy: 0.8809
# Epoch 89/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0805 - accuracy: 0.9732 - val_loss: 0.4342 - val_accuracy: 0.8797
# Epoch 90/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0811 - accuracy: 0.9727 - val_loss: 0.4419 - val_accuracy: 0.8777
# Epoch 91/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0805 - accuracy: 0.9734 - val_loss: 0.4509 - val_accuracy: 0.8793
# Epoch 92/100
# 625/625 [==============================] - 13s 20ms/step - loss: 0.0777 - accuracy: 0.9744 - val_loss: 0.4365 - val_accuracy: 0.8790
# Epoch 93/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0790 - accuracy: 0.9739 - val_loss: 0.4387 - val_accuracy: 0.8795
# Epoch 94/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0778 - accuracy: 0.9741 - val_loss: 0.4385 - val_accuracy: 0.8767
# Epoch 95/100
# 625/625 [==============================] - 13s 21ms/step - loss: 0.0786 - accuracy: 0.9745 - val_loss: 0.4404 - val_accuracy: 0.8805
# Epoch 96/100
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0802 - accuracy: 0.9736 - val_loss: 0.4509 - val_accuracy: 0.8777
# Epoch 97/100
# 625/625 [==============================] - 14s 22ms/step - loss: 0.0788 - accuracy: 0.9742 - val_loss: 0.4332 - val_accuracy: 0.8839
# Epoch 98/100
# 625/625 [==============================] - 15s 23ms/step - loss: 0.0799 - accuracy: 0.9740 - val_loss: 0.4496 - val_accuracy: 0.8790
# Epoch 99/100
# 625/625 [==============================] - 15s 24ms/step - loss: 0.0765 - accuracy: 0.9749 - val_loss: 0.4470 - val_accuracy: 0.8794
# Epoch 100/100
# 625/625 [==============================] - 15s 24ms/step - loss: 0.0775 - accuracy: 0.9741 - val_loss: 0.4468 - val_accuracy: 0.8784

# %%
# se utiliza pandas para visualizar la información almacenada en el diccionario de historia de entrenamiento y graficarla. 
import pandas as pd

pd.DataFrame(history.history).plot(figsize=(6, 3))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# ## **Paso 5.** Evaluación del modelo.
# Se evalua el modelo con el conjunto de datos de prueba.
#
# - X_train: Conjunto de datos de entrenamiento.
# - y_train: Etiquetas de los datos de entrenamiento.
# - X_valid: Conjunto de datos de validación.
# - y_valid: Etiquetas de los datos de validación.
# - X_test: Conjunto de datos de prueba.
# - y_test: Etiquetas de los datos de prueba.

# %%
model = load_model(best_model_name)

# %%
scores_train = model.evaluate(X_train, y_train)
scores_valid = model.evaluate(X_valid, y_valid)
scores_test = model.evaluate(X_test, y_test)
# Out:
# 1250/1250 [==============================] - 6s 4ms/step - loss: 0.0900 - accuracy: 0.9704
# 313/313 [==============================] - 2s 5ms/step - loss: 0.3886 - accuracy: 0.8829
# 313/313 [==============================] - 2s 5ms/step - loss: 0.3904 - accuracy: 0.8809

# %%
print('train loss:', round(scores_train[0]*100,2), '%')
print('valid loss:', round(scores_valid[0]*100,2), '%')
print('test loss:', round(scores_test[0]*100,2), '%')
print("\n")
print('train accuracy:', round(scores_train[1]*100,2), '%')
print('valid accuracy:', round(scores_valid[1]*100,2), '%')
print('test accuracy:', round(scores_test[1]*100,2), '%')
# Out:
# train loss: 9.0 %
# valid loss: 38.86 %
# test loss: 39.04 %
#
#
# train accuracy: 97.04 %
# valid accuracy: 88.29 %
# test accuracy: 88.09 %

# %% [markdown]
# ## **Paso 6.** Usando el modelo para hacer predicciones.
#
# Se toman 5 instancias del set de prueba para hacer la predicción. y se imprime la matriz de probabilidad para cada una de las instancias.

# %%
X_new = X_test[10:15]
y_proba = model.predict(X_new)

# %% [markdown]
# Visualizar las predicciones

# %%
classes_x = np.argmax(y_proba,axis=1)
np.array(class_names)[classes_x]
# Out:
# array(['airplane', 'truck', 'dog', 'horse', 'truck'], dtype='<U10')

# %% [markdown]
# Visualizar los valores reales

# %%
y_new = y_test[10:15]
plt.figure(figsize=(7.2, 2.4))
for index, image in enumerate(X_new):
    plt.subplot(1, 5, index + 1)
    plt.imshow(image, cmap="binary", interpolation="nearest")
    plt.axis('off')
    plt.title(class_names[np.argmax(y_new[index])], fontsize=10)
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()
